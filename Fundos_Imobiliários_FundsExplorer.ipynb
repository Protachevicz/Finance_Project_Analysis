# %% [markdown]
# <img src="https://tradingcomdados.com/images/logotipo/logotipo-trading-com-dados.svg" width="300">

# %% [markdown]
# ---
# # **Análise de Fundos de Investimento Imobiliário (FIIs) com Python**
# ---

# %% [markdown]
# # **1. Bibliotecas utilizadas**

# %%
# Algumas das bibliotecas fundamentais nas técnicas de Webscraping
# Bibliotecas opcionais e menos representativas (por ex., seaborn para colorir dataframe) estarão dispostas ao longo do código
# A instalação é necessária apenas na primeira vez de uso
from itertools import islice

#!pip install requests
#!pip install bs4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# # **2. Webscraping para Rendimentos de Fundos Imobiliários (FIIs)**

# %% [markdown]
# ---
# Como o foco dessa live é a **análise de Fundos Imobiliários**, vamos acelerar a parte de webscraping dos dados. Se for do interesse do público, podemos programar uma próxima live explorando apenas a mineração de dados na web
#
# ---

# %% [markdown]
# https://www.fundsexplorer.com.br/ranking

# %%
FII_url = requests.get("https://www.fundsexplorer.com.br/ranking")
FII_url
# Out:
# <Response [200]>

# %%
FII_url.text
# Out:
# '<!DOCTYPE html>\n<html lang="pt-BR" class="">\n\n<head>\n    <!-- AdOpt -->\n    <!-- <meta name="adopt-website-id" content="2e16f44d-7122-44e3-823d-3153536f3017" />\n    <script src="//tag.goadopt.io/injector.js?website_code=2e16f44d-7122-44e3-823d-3153536f3017" class="adopt-injector"></script> -->\n    <!-- End AdOpt -->\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    <link rel="icon" href="https://www.fundsexplorer.com.br/wp-content/themes/fundsexplorer/resources/images/favicon.ico" type="image/x-icon">\n    <link rel="shortcut icon" href="https://www.fundsexplorer.com.br/wp-content/themes/fundsexplorer/resources/images/favicon.ico" type="image/x-icon">\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n<!-- Checkout Cookie ID -->\n<script type="text/javascript" src="https://www.fundsexplorer.com.br/wp-content/plugins/suno-checkoutcookie/assets/js/frontend.js"></script>\n<!-- Google Tag Manager for WordPress by gtm4wp.com -->\n<script data-cfasync="false" data-pagespeed-no-defer>\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n</script>\n<!-- End Google Tag Manager for WordPress by gtm4wp.com -->\n\t<!-- This site is optimized with the Yoast SEO plugin v21.4 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Ranking de Fundos Imobiliários | FundsExplorer</title>\n\t<link rel="canonical" href="https://www.fundsexplorer.com.br/ranking" />\n\t<meta property="og:locale" content="pt_BR" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Ranking de Fundos Imobiliários | FundsExplorer" />\n\t<meta property="og:url" content="https://www.fundsexplorer.com.br/ranking" />\n\t<meta property="og:site_name" content="FundsExplorer" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://www.fundsexplorer.com.br/ranking","url":"https://www.fundsexplorer.com.br/ranking","name":"Ranking de Fundos Imobiliários | FundsExplorer","isPartOf":{"@id":"https://www.fundsexplorer.com.br/#website"},"datePublished":"2023-02-04T19:51:39+00:00","dateModified":"2023-10-11T16:37:07+00:00","breadcrumb":{"@id":"https://www.fundsexplorer.com.br/ranking#breadcrumb"},"inLanguage":"pt-BR","potentialAction":[{"@type":"ReadAction","target":["https://www.fundsexplorer.com.br/ranking"]}]},{"@type":"BreadcrumbList","@id":"https://www.fundsexplorer.com.br/ranking#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.fundsexplorer.com.br/"},{"@type":"ListItem","position":2,"name":"Ranking de Fundos Imobiliários"}]},{"@type":"WebSite","@id":"https://www.fundsexplorer.com.br/#website","url":"https://www.fundsexplorer.com.br/","name":"FundsExplorer","description":"Funds Explorer","alternateName":"Funds Explorer","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.fundsexplorer.com.br/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"pt-BR"}]}</script>\n\t<!-- / Yoast SEO plugin. -->\n\n\n<link rel=\'dns-prefetch\' href=\'//cdnjs.cloudflare.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.fundsexplorer.com.br\' />\n<link rel=\'dns-prefetch\' href=\'//files.fundsexplorer.com.br\' />\n<link rel="alternate" type="application/rss+xml" title="Feed para FundsExplorer &raquo;" href="https://www.fundsexplorer.com.br/feed" />\n<link rel="alternate" type="application/rss+xml" title="Feed de comentários para FundsExplorer &raquo;" href="https://www.fundsexplorer.com.br/comments/feed" />\n<style id=\'classic-theme-styles-inline-css\' type=\'text/css\'>\n/*! This file is auto-generated */\n.wp-block-button__link{color:#fff;background-color: ...

# %%
FII_bs4 = BeautifulSoup(FII_url.text, "html.parser")
#FII_bs4.head()

# %%
#FII_bs4

# %%
#FII_table = FII_bs4.findAll(attrs = {'id':'scroll-wrapper'})
#FII_table = FII_bs4.findAll(attrs = {'id':'containerBackToUp'})

#FII_table = FII_bs4.findAll(attrs = {'id':'#upTo--default-fiis-table'})

#FII_table = FII_bs4.findAll(attrs = {'id':'scroll-table-container'})

# %%
#FII_table

# %%
#FII_df = pd.read_html(str(FII_table[0]))[0]

# %%
#FII_df.columns

# %% [markdown]
# Aqui temos o diamante bruto, os dados de todos os FIIs disponíveis (número de linhas do dataframe), com todos os seus multiplos parametros (número de colunas df)

# %%
#str(list(FII_df['Código do fundo'].sort_values()))

# %%
#print(FII_table)

# %%
from google.colab import auth
#auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# Código da planilha

# %%
SHEET_ID = '1mWc_h8cubvNogLs9m50vrnSM66KFFuQ2a2gVeI6HLac'
SHEET_NAME = 'AAPL'
url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME}'
df_1 = pd.read_csv(url)
df_1.head()
# Out:
#    FUNDOS               SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  P/VP  \
# 0  AAZQ11          INDEFINIDO             9,06           800.151,05  0,94
# 1  ABCP11           SHOPPINGS            76,68            64.689,36  0,76
# 2  AFHI11              PAPÉIS            98,30         1.500.508,45  1,02
# 3  AGRX11              OUTROS            10,49           387.323,55   NaN
# 4  AIEC11  LAJES CORPORATIVAS            52,23           480.959,68  0,62
#
#   ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0             0,12         1,31 %            3,90 %            7,85 %
# 1             0,50         0,64 %            2,34 %            5,00 %
# 2             0,95         0,97 %            2,93 %            6,09 %
# 3             0,12         1,12 %            3,80 %            7,96 %
# 4             0,71         1,35 %            3,07 %            8,11 %
#
#   DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0            15,52 %  ...         1,25 %               0,00 %
# 1             9,44 %  ...         0,81 %              10,34 %
# 2            12,79 %  ...         0,98 %               1,71 %
# 3            16,56 %  ...            NaN                  NaN
# 4            15,03 %  ...         0,20 %             -10,18 %
#
#   RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                0,00 %                  0,00 %             0        13,22
# 1               11,23 %                 19,14 %             1        15,42
# 2                2,71 %                  9,15 %             0          8,1
# 3                   NaN                     NaN             0        13,35
# 4              -10,00 %                 -8,96 %             4        16,84
#
#   NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0        27.598         NaN              NaN                NaN
# 1        16.988         NaN              NaN                NaN
# 2        31.221         NaN              NaN                NaN
# 3             0         NaN              NaN                NaN
# 4             1         NaN              NaN                NaN
#
# [5 rows x 30 columns]

# %%
df_1.tail()
# Out:
#       FUNDOS                     SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  \
# 447   XTED11        LAJES CORPORATIVAS             8,82            17.641,88
# 448   YUFI11  FUNDO DE DESENVOLVIMENTO              105             5.044,33
# 449  YUFI11B                INDEFINIDO              NaN                  NaN
# 450   ZAVI11                INDEFINIDO           129,09           682.267,50
# 451   ZIFI11  FUNDO DE DESENVOLVIMENTO           849,99             4.362,87
#
#      P/VP ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 447  0,68            11,16            NaN               NaN               NaN
# 448  1,03             0,39         0,00 %            0,00 %            0,00 %
# 449   NaN             0,63         0,00 %            0,00 %            0,00 %
# 450  0,97             1,34         1,01 %            3,01 %            5,85 %
# 451  0,71             3,31         0,00 %            0,00 %            0,00 %
#
#     DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 447                NaN  ...         0,00 %              -0,36 %
# 448             1,09 %  ...            NaN                  NaN
# 449             0,00 %  ...         0,60 %              -0,01 %
# 450            11,22 %  ...            NaN                  NaN
# 451             0,00 %  ...            NaN                  NaN
#
#     RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 447               -0,36 %                 -3,45 %             1        29,46
# 448                   NaN                     NaN            28       268,47
# 449                0,59 %                  6,32 %             0          NaN
# 450                   NaN                     NaN            10        22,86
# 451                   NaN                     NaN             0        74,32
#
#     NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 447         4.098         NaN              NaN                NaN
# 448            62         NaN              NaN                NaN
# 449             0         NaN              NaN                NaN
# 450         5.692         NaN              NaN                NaN
# 451            73         NaN              NaN                NaN
#
# [5 rows x 30 columns]

# %%
FII_df = df_1

# %% [markdown]
# # **3. Organização dos dados extraídos**

# %% [markdown]
# **Observação**: existem diversas formas muito mais elegantes de manipulação desses dados, usando estruturas condicionais e de repetição, por exemplo<p>
# Entretanto, vamos tentar trazer essa manipulação usando funções e métodos mais simples, mesmo que exijam algumas etapas extras

# %%
# Faremos uma cópia do dataframe para manipulá-lo com mais liberdade e, caso
# editemos algo, possamos reverter a ediçao sem um novo webscraping

FII_df_backup = FII_df.copy()

# %%
FII_df.head()
# Out:
#    FUNDOS               SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  P/VP  \
# 0  AAZQ11          INDEFINIDO             9,06           800.151,05  0,94
# 1  ABCP11           SHOPPINGS            76,68            64.689,36  0,76
# 2  AFHI11              PAPÉIS            98,30         1.500.508,45  1,02
# 3  AGRX11              OUTROS            10,49           387.323,55   NaN
# 4  AIEC11  LAJES CORPORATIVAS            52,23           480.959,68  0,62
#
#   ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0             0,12         1,31 %            3,90 %            7,85 %
# 1             0,50         0,64 %            2,34 %            5,00 %
# 2             0,95         0,97 %            2,93 %            6,09 %
# 3             0,12         1,12 %            3,80 %            7,96 %
# 4             0,71         1,35 %            3,07 %            8,11 %
#
#   DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0            15,52 %  ...         1,25 %               0,00 %
# 1             9,44 %  ...         0,81 %              10,34 %
# 2            12,79 %  ...         0,98 %               1,71 %
# 3            16,56 %  ...            NaN                  NaN
# 4            15,03 %  ...         0,20 %             -10,18 %
#
#   RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                0,00 %                  0,00 %             0        13,22
# 1               11,23 %                 19,14 %             1        15,42
# 2                2,71 %                  9,15 %             0          8,1
# 3                   NaN                     NaN             0        13,35
# 4              -10,00 %                 -8,96 %             4        16,84
#
#   NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0        27.598         NaN              NaN                NaN
# 1        16.988         NaN              NaN                NaN
# 2        31.221         NaN              NaN                NaN
# 3             0         NaN              NaN                NaN
# 4             1         NaN              NaN                NaN
#
# [5 rows x 30 columns]

# %%
FII_df.dtypes
# Out:
# FUNDOS                      object
# SETOR                       object
# PREÇO ATUAL (R$)            object
# LIQUIDEZ DIÁRIA (R$)        object
# P/VP                        object
# ÚLTIMO DIVIDENDO            object
# DIVIDEND YIELD              object
# DY (3M) ACUMULADO           object
# DY (6M) ACUMULADO           object
# DY (12M) ACUMULADO          object
# DY (3M) MÉDIA               object
# DY (6M) MÉDIA               object
# DY (12M) MÉDIA              object
# DY ANO                      object
# VARIAÇÃO PREÇO              object
# RENTAB. PERÍODO             object
# RENTAB. ACUMULADA           object
# PATRIMÔNIO LÍQUIDO          object
# VPA                         object
# P/VPA                       object
# DY PATRIMONIAL              object
# VARIAÇÃO PATRIMONIAL        object
# RENTAB. PATR. PERÍODO       object
# RENTAB. PATR. ACUMULADA     object
# QUANT. ATIVOS                int64
# VOLATILIDADE                object
# NUM. COTISTAS               object
# TAX. GESTÃO                float64
# TAX. PERFORMANCE           float64
# TAX. ADMINISTRAÇÃO         float64
# dtype: object

# %%
# Erro esperado, pois a variável não é float
#np.max(FII_df['Preço Atual'])

# %%
FII_df['PREÇO ATUAL (R$)']
# Out:
# 0        9,06
# 1       76,68
# 2       98,30
# 3       10,49
# 4       52,23
#         ...
# 447      8,82
# 448       105
# 449       NaN
# 450    129,09
# 451    849,99
# Name: PREÇO ATUAL (R$), Length: 452, dtype: object

# %%
FII_df.iloc[0]
# Out:
# FUNDOS                             AAZQ11
# SETOR                          INDEFINIDO
# PREÇO ATUAL (R$)                     9,06
# LIQUIDEZ DIÁRIA (R$)           800.151,05
# P/VP                                 0,94
# ÚLTIMO DIVIDENDO                     0,12
# DIVIDEND YIELD                     1,31 %
# DY (3M) ACUMULADO                  3,90 %
# DY (6M) ACUMULADO                  7,85 %
# DY (12M) ACUMULADO                15,52 %
# DY (3M) MÉDIA                      1,30 %
# DY (6M) MÉDIA                      1,31 %
# DY (12M) MÉDIA                     1,29 %
# DY ANO                             5,22 %
# VARIAÇÃO PREÇO                     0,44 %
# RENTAB. PERÍODO                    1,75 %
# RENTAB. ACUMULADA                  6,36 %
# PATRIMÔNIO LÍQUIDO         230.857.797,15
# VPA                                   9,6
# P/VPA                                0,94
# DY PATRIMONIAL                     1,25 %
# VARIAÇÃO PATRIMONIAL               0,00 %
# RENTAB. PATR. PERÍODO              0,00 %
# RENTAB. PATR. ACUMULADA            0,00 %
# QUANT. ATIVOS                           0
# VOLATILIDADE                        13,22
# NUM. COTISTAS                      27.598
# TAX. GESTÃO                           NaN
# TAX. PERFORMANCE                      NaN
# TAX. ADMINISTRAÇÃO                    NaN
# Name: 0, dtype: object

# %%
FII_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FUNDOS                   452 non-null    object
#  1   SETOR                    451 non-null    object
#  2   PREÇO ATUAL (R$)         416 non-null    object
#  3   LIQUIDEZ DIÁRIA (R$)     408 non-null    object
#  4   P/VP                     386 non-null    object
#  5   ÚLTIMO DIVIDENDO         452 non-null    object
#  6   DIVIDEND YIELD           417 non-null    object
#  7   DY (3M) ACUMULADO        417 non-null    object
#  8   DY (6M) ACUMULADO        417 non-null    object
#  9   DY (12M) ACUMULADO       417 non-null    object
#  10  DY (3M) MÉDIA            417 non-null    object
#  11  DY (6M) MÉDIA            417 non-null    object
#  12  DY (12M) MÉDIA           417 non-null    object
#  13  DY ANO                   416 non-null    object
#  14  VARIAÇÃO PREÇO           417 non-null    object
#  15  RENTAB. PERÍODO          417 non-null    object
#  16  RENTAB. ACUMULADA        313 non-null    object
#  17  PATRIMÔNIO LÍQUIDO       415 non-null    object
#  18  VPA                      296 non-null    object
#  19  P/VPA                    288 non-null    object
#  20  DY PATRIMONIAL           298 non-null    object
#  21  VARIAÇÃO PATRIMONIAL     298 non-null    object
#  22  RENTAB. PATR. PERÍODO    298 non-null    object
#  23  RENTAB. PATR. ACUMULADA  298 non-null    object
#  24  QUANT. ATIVOS            452 non-null    int64
#  25  VOLATILIDADE             403 non-null    object
#  26  NUM. COTISTAS            452 non-null    object
#  27  TAX. GESTÃO              0 non-null      float64
#  28  TAX. PERFORMANCE         0 non-null      float64
#  29  TAX. ADMINISTRAÇÃO       0 non-null      float64
# dtypes: float64(3), int64(1), object(26)
# memory usage: 106.1+ KB

# %%
FII_df = FII_df.replace(to_replace = r'^R\$ ', value = '', regex = True)

# %%
FII_df.head()
# Out:
#    FUNDOS               SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  P/VP  \
# 0  AAZQ11          INDEFINIDO             9,06           800.151,05  0,94
# 1  ABCP11           SHOPPINGS            76,68            64.689,36  0,76
# 2  AFHI11              PAPÉIS            98,30         1.500.508,45  1,02
# 3  AGRX11              OUTROS            10,49           387.323,55   NaN
# 4  AIEC11  LAJES CORPORATIVAS            52,23           480.959,68  0,62
#
#   ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0             0,12         1,31 %            3,90 %            7,85 %
# 1             0,50         0,64 %            2,34 %            5,00 %
# 2             0,95         0,97 %            2,93 %            6,09 %
# 3             0,12         1,12 %            3,80 %            7,96 %
# 4             0,71         1,35 %            3,07 %            8,11 %
#
#   DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0            15,52 %  ...         1,25 %               0,00 %
# 1             9,44 %  ...         0,81 %              10,34 %
# 2            12,79 %  ...         0,98 %               1,71 %
# 3            16,56 %  ...            NaN                  NaN
# 4            15,03 %  ...         0,20 %             -10,18 %
#
#   RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                0,00 %                  0,00 %             0        13,22
# 1               11,23 %                 19,14 %             1        15,42
# 2                2,71 %                  9,15 %             0          8,1
# 3                   NaN                     NaN             0        13,35
# 4              -10,00 %                 -8,96 %             4        16,84
#
#   NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0        27.598         NaN              NaN                NaN
# 1        16.988         NaN              NaN                NaN
# 2        31.221         NaN              NaN                NaN
# 3             0         NaN              NaN                NaN
# 4             1         NaN              NaN                NaN
#
# [5 rows x 30 columns]

# %%
FII_df
# Out:
#       FUNDOS                     SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  \
# 0     AAZQ11                INDEFINIDO             9,06           800.151,05
# 1     ABCP11                 SHOPPINGS            76,68            64.689,36
# 2     AFHI11                    PAPÉIS            98,30         1.500.508,45
# 3     AGRX11                    OUTROS            10,49           387.323,55
# 4     AIEC11        LAJES CORPORATIVAS            52,23           480.959,68
# ..       ...                       ...              ...                  ...
# 447   XTED11        LAJES CORPORATIVAS             8,82            17.641,88
# 448   YUFI11  FUNDO DE DESENVOLVIMENTO              105             5.044,33
# 449  YUFI11B                INDEFINIDO              NaN                  NaN
# 450   ZAVI11                INDEFINIDO           129,09           682.267,50
# 451   ZIFI11  FUNDO DE DESENVOLVIMENTO           849,99             4.362,87
#
#      P/VP ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0    0,94             0,12         1,31 %            3,90 %            7,85 %
# 1    0,76             0,50         0,64 %            2,34 %            5,00 %
# 2    1,02             0,95         0,97 %            2,93 %            6,09 %
# 3     NaN             0,12         1,12 %            3,80 %            7,96 %
# 4    0,62             0,71         1,35 %            3,07 %            8,11 %
# ..    ...              ...            ...               ...               ...
# 447  0,68            11,16            NaN               NaN               NaN
# 448  1,03             0,39         0,00 %            0,00 %            0,00 %
# 449   NaN             0,63         0,00 %            0,00 %            0,00 %
# 450  0,97             1,34         1,01 %            3,01 %            5,85 %
# 451  0,71             3,31         0,00 %            0,00 %            0,00 %
#
#     DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0              15,52 %  ...         1,25 %               0,00 %
# 1               9,44 %  ...         0,81 %              10,34 %
# 2              12,79 %  ...         0,98 %               1,71 %
# 3              16,56 %  ...            NaN                  NaN
# 4              15,03 %  ...         0,20 %             -10,18 %
# ..                 ...  ...            ...                  ...
# 447                NaN  ...         0,00 %              -0,36 %
# 448             1,09 %  ...            NaN                  NaN
# 449             0,00 %  ...         0,60 %              -0,01 %
# 450            11,22 %  ...            NaN                  NaN
# 451             0,00 %  ...            NaN                  NaN
#
#     RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                  0,00 %                  0,00 %             0        13,22
# 1                 11,23 %                 19,14 %             1        15,42
# 2                  2,71 %                  9,15 %             0          8,1
# 3                     NaN                     NaN             0        13,35
# 4                -10,00 %                 -8,96 %             4        16,84
# ..                    ...                     ...           ...          ...
# 447               -0,36 %                 -3,45 %             1        29,46
# 448                   NaN                     NaN            28       268,47
# 449                0,59 %                  6,32 %             0          NaN
# 450                   NaN                     NaN            10        22,86
# 451                   NaN                     NaN             0        74,32
#
#     NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0          27.598         NaN              NaN                NaN
# 1          16.988         NaN              NaN                NaN
# 2          31.221         NaN              NaN                NaN
# 3               0         NaN              NaN                NaN
# 4               1         NaN              NaN                NaN
# ..            ...         ...              ...                ...
# 447         4.098         NaN              NaN                NaN
# 448            62         NaN              NaN                NaN
# 449             0         NaN              NaN                NaN
# 450         5.692         NaN              NaN                NaN
# 451            73         NaN              NaN                NaN
#
# [452 rows x 30 columns]

# %%
# Outro problema é o separador decimal (atualmente como vírgula). Entretanto, não podemos simplesmente substituir por '.' diretamente pois podem existir valores com '.' como separador de milhar
# Agravante extra: em algumas columas o separador decimal está como ',' e outros como '.'

FII_df['PATRIMÔNIO LÍQUIDO']
# Out:
# 0      230.857.797,15
# 1      477.089.865,14
# 2      386.055.547,13
# 3                 NaN
# 4      405.272.651,50
#             ...
# 447     67.378.204,04
# 448     50.018.722,37
# 449               NaN
# 450    156.260.474,71
# 451     56.904.044,67
# Name: PATRIMÔNIO LÍQUIDO, Length: 452, dtype: object

# %%
FII_df['PATRIMÔNIO LÍQUIDO'] = FII_df['PATRIMÔNIO LÍQUIDO'].str.replace('.','')
FII_df['LIQUIDEZ DIÁRIA (R$)'] = FII_df['LIQUIDEZ DIÁRIA (R$)'].str.replace('.','')

FII_df['PREÇO ATUAL (R$)'] = FII_df['PREÇO ATUAL (R$)'].str.replace('.','')
FII_df['ÚLTIMO DIVIDENDO'] = FII_df['ÚLTIMO DIVIDENDO'].str.replace('.','')
FII_df['P/VPA'] = FII_df['P/VPA'].str.replace('.','')
FII_df['P/VP'] = FII_df['P/VP'].str.replace('.','')
FII_df['VPA'] = FII_df['VPA'].str.replace('.','')

# %%
FII_df.head()
# Out:
#    FUNDOS               SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  P/VP  \
# 0  AAZQ11          INDEFINIDO             9,06            800151,05  0,94
# 1  ABCP11           SHOPPINGS            76,68             64689,36  0,76
# 2  AFHI11              PAPÉIS            98,30           1500508,45  1,02
# 3  AGRX11              OUTROS            10,49            387323,55   NaN
# 4  AIEC11  LAJES CORPORATIVAS            52,23            480959,68  0,62
#
#   ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0             0,12         1,31 %            3,90 %            7,85 %
# 1             0,50         0,64 %            2,34 %            5,00 %
# 2             0,95         0,97 %            2,93 %            6,09 %
# 3             0,12         1,12 %            3,80 %            7,96 %
# 4             0,71         1,35 %            3,07 %            8,11 %
#
#   DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0            15,52 %  ...         1,25 %               0,00 %
# 1             9,44 %  ...         0,81 %              10,34 %
# 2            12,79 %  ...         0,98 %               1,71 %
# 3            16,56 %  ...            NaN                  NaN
# 4            15,03 %  ...         0,20 %             -10,18 %
#
#   RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                0,00 %                  0,00 %             0        13,22
# 1               11,23 %                 19,14 %             1        15,42
# 2                2,71 %                  9,15 %             0          8,1
# 3                   NaN                     NaN             0        13,35
# 4              -10,00 %                 -8,96 %             4        16,84
#
#   NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0        27.598         NaN              NaN                NaN
# 1        16.988         NaN              NaN                NaN
# 2        31.221         NaN              NaN                NaN
# 3             0         NaN              NaN                NaN
# 4             1         NaN              NaN                NaN
#
# [5 rows x 30 columns]

# %%
FII_df
# Out:
#       FUNDOS                     SETOR PREÇO ATUAL (R$) LIQUIDEZ DIÁRIA (R$)  \
# 0     AAZQ11                INDEFINIDO             9,06            800151,05
# 1     ABCP11                 SHOPPINGS            76,68             64689,36
# 2     AFHI11                    PAPÉIS            98,30           1500508,45
# 3     AGRX11                    OUTROS            10,49            387323,55
# 4     AIEC11        LAJES CORPORATIVAS            52,23            480959,68
# ..       ...                       ...              ...                  ...
# 447   XTED11        LAJES CORPORATIVAS             8,82             17641,88
# 448   YUFI11  FUNDO DE DESENVOLVIMENTO              105              5044,33
# 449  YUFI11B                INDEFINIDO              NaN                  NaN
# 450   ZAVI11                INDEFINIDO           129,09            682267,50
# 451   ZIFI11  FUNDO DE DESENVOLVIMENTO           849,99              4362,87
#
#      P/VP ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0    0,94             0,12         1,31 %            3,90 %            7,85 %
# 1    0,76             0,50         0,64 %            2,34 %            5,00 %
# 2    1,02             0,95         0,97 %            2,93 %            6,09 %
# 3     NaN             0,12         1,12 %            3,80 %            7,96 %
# 4    0,62             0,71         1,35 %            3,07 %            8,11 %
# ..    ...              ...            ...               ...               ...
# 447  0,68            11,16            NaN               NaN               NaN
# 448  1,03             0,39         0,00 %            0,00 %            0,00 %
# 449   NaN             0,63         0,00 %            0,00 %            0,00 %
# 450  0,97             1,34         1,01 %            3,01 %            5,85 %
# 451  0,71             3,31         0,00 %            0,00 %            0,00 %
#
#     DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0              15,52 %  ...         1,25 %               0,00 %
# 1               9,44 %  ...         0,81 %              10,34 %
# 2              12,79 %  ...         0,98 %               1,71 %
# 3              16,56 %  ...            NaN                  NaN
# 4              15,03 %  ...         0,20 %             -10,18 %
# ..                 ...  ...            ...                  ...
# 447                NaN  ...         0,00 %              -0,36 %
# 448             1,09 %  ...            NaN                  NaN
# 449             0,00 %  ...         0,60 %              -0,01 %
# 450            11,22 %  ...            NaN                  NaN
# 451             0,00 %  ...            NaN                  NaN
#
#     RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                  0,00 %                  0,00 %             0        13,22
# 1                 11,23 %                 19,14 %             1        15,42
# 2                  2,71 %                  9,15 %             0          8,1
# 3                     NaN                     NaN             0        13,35
# 4                -10,00 %                 -8,96 %             4        16,84
# ..                    ...                     ...           ...          ...
# 447               -0,36 %                 -3,45 %             1        29,46
# 448                   NaN                     NaN            28       268,47
# 449                0,59 %                  6,32 %             0          NaN
# 450                   NaN                     NaN            10        22,86
# 451                   NaN                     NaN             0        74,32
#
#     NUM. COTISTAS TAX. GESTÃO TAX. PERFORMANCE TAX. ADMINISTRAÇÃO
# 0          27.598         NaN              NaN                NaN
# 1          16.988         NaN              NaN                NaN
# 2          31.221         NaN              NaN                NaN
# 3               0         NaN              NaN                NaN
# 4               1         NaN              NaN                NaN
# ..            ...         ...              ...                ...
# 447         4.098         NaN              NaN                NaN
# 448            62         NaN              NaN                NaN
# 449             0         NaN              NaN                NaN
# 450         5.692         NaN              NaN                NaN
# 451            73         NaN              NaN                NaN
#
# [452 rows x 30 columns]

# %%
# Segunda etapa: substituir as ',' por '.' (separador decimal padrão para executarmos as análises estatísticas exploratórias dos dados)
# Agora também converteremos os dados em float (formato de números decimais)

pl = "PATRIMÔNIO LÍQUIDO"
pa= "PREÇO ATUAL (R$)"
ud = "ÚLTIMO DIVIDENDO"

FII_df[f'{pl}'] = FII_df[f'{pl}'].str.replace(',','.')

FII_df[f'{pa}'] = FII_df[f'{pa}'].str.replace(',','.')
FII_df[f'{ud}'] = FII_df[f'{ud}'].str.replace(',','.')
FII_df['VPA'] = FII_df['VPA'].str.replace(',','.')
FII_df['P/VPA'] = FII_df['P/VPA'].str.replace(',','.')
FII_df['P/VP'] = FII_df['P/VP'].str.replace(',','.')
FII_df['LIQUIDEZ DIÁRIA (R$)'] = FII_df['LIQUIDEZ DIÁRIA (R$)'].str.replace(',','.')
FII_df['VOLATILIDADE'] = FII_df['VOLATILIDADE'].str.replace('.','')
FII_df['VOLATILIDADE'] = FII_df['VOLATILIDADE'].str.replace(',','.')

# %%
FII_df[f'{pl}']  = FII_df[f'{pl}'] .astype(float)
FII_df[f'{pa}']  = FII_df[f'{pa}'] .astype(float)
FII_df[f'{ud}']  = FII_df[f'{ud}'] .astype(float)
FII_df['VPA']  = FII_df['VPA'] .astype(float)
FII_df['P/VPA']  = FII_df['P/VPA'] .astype(float)
FII_df['P/VP']  = FII_df['P/VP'].astype(float)
FII_df['LIQUIDEZ DIÁRIA (R$)'] = FII_df['LIQUIDEZ DIÁRIA (R$)'].astype(float)
FII_df['VOLATILIDADE'] = FII_df['VOLATILIDADE'].astype(float)

# %%
FII_df[f'{pl}']
# Out:
# 0      2.308578e+08
# 1      4.770899e+08
# 2      3.860555e+08
# 3               NaN
# 4      4.052727e+08
#            ...
# 447    6.737820e+07
# 448    5.001872e+07
# 449             NaN
# 450    1.562605e+08
# 451    5.690404e+07
# Name: PATRIMÔNIO LÍQUIDO, Length: 452, dtype: float64

# %%
np.max(FII_df[f'{pa}'] )
# Out:
# 94794.81

# %%
np.min(FII_df[f'{pa}'] )
# Out:
# 0.21

# %%
np.min(FII_df[f'{pl}'] )
# Out:
# -16623707.19

# %%
FII_df.iloc[0:10].transpose()
# Out:
#                                     0             1             2          3  \
# FUNDOS                         AAZQ11        ABCP11        AFHI11     AGRX11
# SETOR                      INDEFINIDO     SHOPPINGS        PAPÉIS     OUTROS
# PREÇO ATUAL (R$)                 9.06         76.68          98.3      10.49
# LIQUIDEZ DIÁRIA (R$)        800151.05      64689.36    1500508.45  387323.55
# P/VP                             0.94          0.76          1.02        NaN
# ÚLTIMO DIVIDENDO                 0.12           0.5          0.95       0.12
# DIVIDEND YIELD                 1,31 %        0,64 %        0,97 %     1,12 %
# DY (3M) ACUMULADO              3,90 %        2,34 %        2,93 %     3,80 %
# DY (6M) ACUMULADO              7,85 %        5,00 %        6,09 %     7,96 %
# DY (12M) ACUMULADO            15,52 %        9,44 %       12,79 %    16,56 %
# DY (3M) MÉDIA                  1,30 %        0,78 %        0,98 %     1,27 %
# DY (6M) MÉDIA                  1,31 %        0,83 %        1,02 %     1,33 %
# DY (12M) MÉDIA                 1,29 %        0,79 %        1,07 %     1,38 %
# DY ANO                         5,22 %        3,27 %        2,93 %     3,80 %
# VARIAÇÃO PREÇO                 0,44 %       -3,67 %       -0,51 %    -0,19 %
# RENTAB. PERÍODO                1,75 %       -3,05 %        0,46 %     0,93 %
# RENTAB. ACUMULADA              6,36 %       15,66 %        3,98 %     1,29 %
# PATRIMÔNIO LÍQUIDO       230857797.15  477089865.14  386055547.13        NaN
# VPA                               9.6        101.31         96.59        NaN
# P/VPA                            0.94          0.76          1.02        NaN
# DY PATRIMONIAL                 1,25 %        0,81 %        0,98 %        NaN
# VARIAÇÃO PATRIMONIAL           0,00 %       10,34 %        1,71 %        NaN
# RENTAB. PATR. PERÍODO          0,00 %       11,23 %        2,71 %        NaN
# RENTAB. PATR. ACUMULADA        0,00 %       19,14 %        9,15 %        NaN
# QUANT. ATIVOS                       0             1             0          0
# VOLATILIDADE                    13.22         15.42           8.1      13.35
# NUM. COTISTAS                  27.598        16.988        31.221          0
# TAX. GESTÃO                       NaN           NaN           NaN        NaN
# TAX. PERFORMANCE                  NaN           NaN           NaN        NaN
# TAX. ADMINISTRAÇÃO                NaN           NaN           NaN        NaN
#
#                                           4             5                   6  \
# FUNDOS                               AIEC11        AJFI11              ALMI11
# SETOR                    LAJES CORPORATIVAS     SHOPPINGS  LAJES CORPORATIVAS
# PREÇO ATUAL (R$)                      52.23          9.74               656.0
# LIQUIDEZ DIÁRIA (R$)              480959.68     800840.36            62803.27
# P/VP                                   0.62          0.78                 0.3
# ÚLTIMO DIVIDENDO                       0.71          0.08                0.37
# DIVIDEND YIELD                       1,35 %        0,81 %              0,00 %
# DY (3M) ACUMULADO                    3,07 %        1,64 %              0,00 %
# DY (6M) ACUMULADO                    8,11 %        1,64 %              0,00 %
# DY (12M) ACUMULADO                  15,03 %        1,64 %              0,00 %
# DY (3M) MÉDIA                        1,02 %        0,82 %              0,00 %
# DY (6M) MÉDIA                        1,35 %        0,82 %              0,00 %
# DY (12M) MÉDIA                       1,25 %        0,82 %              0,00 %
# DY ANO                               5,40 %        1,64 %              0,00 %
# VARIAÇÃO PREÇO                       4,78 %       -0,71 %              0,00 %
# RENTAB. PERÍODO                      6,19 %        0,10 %              0,00 %
# RENTAB. ACUMULADA                   -0,81 %        0,10 %                 NaN
# PATRIMÔNIO LÍQUIDO              405272651.5  394131222.07        240187303.24
# VPA                                   83.99           NaN             2046.78
# P/VPA                                  0.62           NaN                0.32
# DY PATRIMONIAL                       0,20 %           NaN              0,00 %
# VARIAÇÃO PATRIMONIAL               -10,18 %           NaN             -0,05 %
# RENTAB. PATR. PERÍODO              -10,00 %           NaN             -0,05 %
# RENTAB. PATR. ACUMULADA             -8,96 %           NaN              0,90 %
# QUANT. ATIVOS                             4             0                   1
# VOLATILIDADE                          16.84         15.02               34.08
# NUM. COTISTAS                             1        11.173               2.209
# TAX. GESTÃO                             NaN           NaN                 NaN
# TAX. PERFORMANCE                        NaN           NaN                 NaN
# TAX. ADMINISTRAÇÃO                      NaN           NaN                 NaN
#
#                                        7              8                     9
# FUNDOS                            ALZM11         ALZR11                APTO11
# SETOR                    FUNDO DE FUNDOS          MISTO  IMÓVEIS RESIDENCIAIS
# PREÇO ATUAL (R$)                    8.47         118.05                  9.64
# LIQUIDEZ DIÁRIA (R$)           186783.77      1331515.0              35401.95
# P/VP                                 1.0           1.11                  0.95
# ÚLTIMO DIVIDENDO                    0.09            0.8                  0.09
# DIVIDEND YIELD                    0,98 %         0,68 %                0,93 %
# DY (3M) ACUMULADO                 3,23 %         2,02 %                2,79 %
# DY (6M) ACUMULADO                 6,17 %         4,15 %                5,56 %
# DY (12M) ACUMULADO               11,55 %         8,43 %               12,12 %
# DY (3M) MÉDIA                     1,08 %         0,67 %                0,93 %
# DY (6M) MÉDIA                     1,03 %         0,69 %                0,93 %
# DY (12M) MÉDIA                    0,96 %         0,70 %                1,01 %
# DY ANO                            3,23 %         2,02 %                3,71 %
# VARIAÇÃO PREÇO                   -0,91 %        -0,30 %                1,68 %
# RENTAB. PERÍODO                   0,06 %         0,37 %                2,62 %
# RENTAB. ACUMULADA                 3,86 %         2,64 %                3,55 %
# PATRIMÔNIO LÍQUIDO          128894672.43  1047943303.45           46958948.53
# VPA                                 8.49         106.28                 10.18
# P/VPA                                1.0           1.11                  0.95
# DY PATRIMONIAL                    1,06 %         0,75 %                0,88 %
# VARIAÇÃO PATRIMONIAL            -90,83 %        -0,57 %                2,21 %
# RENTAB. PATR. PERÍODO           -90,73 %         0,18 %                3,11 %
# RENTAB. PATR. ACUMULADA         -90,34 %         8,19 %               17,74 %
# QUANT. ATIVOS                          0             14                     4
# VOLATILIDADE                       17.22          10.81                 16.32
# NUM. COTISTAS                      9.254        147.616                10.057
# TAX. GESTÃO                          NaN            NaN                   NaN
# TAX. PERFORMANCE                     NaN            NaN                   NaN
# TAX. ADMINISTRAÇÃO                   NaN            NaN                   NaN

# %%
FII_df = FII_df.replace(to_replace = r'%$', value = '', regex = True)
FII_df.head()
# Out:
#    FUNDOS               SETOR  PREÇO ATUAL (R$)  LIQUIDEZ DIÁRIA (R$)  P/VP  \
# 0  AAZQ11          INDEFINIDO              9.06             800151.05  0.94
# 1  ABCP11           SHOPPINGS             76.68              64689.36  0.76
# 2  AFHI11              PAPÉIS             98.30            1500508.45  1.02
# 3  AGRX11              OUTROS             10.49             387323.55   NaN
# 4  AIEC11  LAJES CORPORATIVAS             52.23             480959.68  0.62
#
#    ÚLTIMO DIVIDENDO DIVIDEND YIELD DY (3M) ACUMULADO DY (6M) ACUMULADO  \
# 0              0.12          1,31              3,90              7,85
# 1              0.50          0,64              2,34              5,00
# 2              0.95          0,97              2,93              6,09
# 3              0.12          1,12              3,80              7,96
# 4              0.71          1,35              3,07              8,11
#
#   DY (12M) ACUMULADO  ... DY PATRIMONIAL VARIAÇÃO PATRIMONIAL  \
# 0             15,52   ...          1,25                 0,00
# 1              9,44   ...          0,81                10,34
# 2             12,79   ...          0,98                 1,71
# 3             16,56   ...            NaN                  NaN
# 4             15,03   ...          0,20               -10,18
#
#   RENTAB. PATR. PERÍODO RENTAB. PATR. ACUMULADA QUANT. ATIVOS VOLATILIDADE  \
# 0                 0,00                    0,00              0        13.22
# 1                11,23                   19,14              1        15.42
# 2                 2,71                    9,15              0         8.10
# 3                   NaN                     NaN             0        13.35
# 4               -10,00                   -8,96              4        16.84
#
#   NUM. COTISTAS  TAX. GESTÃO  TAX. PERFORMANCE  TAX. ADMINISTRAÇÃO
# 0        27.598          NaN               NaN                 NaN
# 1        16.988          NaN               NaN                 NaN
# 2        31.221          NaN               NaN                 NaN
# 3             0          NaN               NaN                 NaN
# 4             1          NaN               NaN                 NaN
#
# [5 rows x 30 columns]

# %%
set(FII_df.SETOR)
# Out:
# {'AGÊNCIAS DE BANCOS',
#  'EDUCACIONAL',
#  'FIAGRO',
#  'FUNDO DE DESENVOLVIMENTO',
#  'FUNDO DE FUNDOS',
#  'HOSPITALAR',
#  'HOTÉIS',
#  'IMÓVEIS COMERCIAIS - OUTROS',
#  'IMÓVEIS INDUSTRIAIS E LOGÍSTICOS',
#  'IMÓVEIS RESIDENCIAIS',
#  'INDEFINIDO',
#  'LAJES CORPORATIVAS',
#  'MISTO',
#  'OUTROS',
#  'PAPÉIS',
#  'SHOPPINGS',
#  'VAREJO',
#  nan}

# %%
dy = 'DIVIDEND YIELD'
FII_df[f"{dy}"] = FII_df[f"{dy}"].str.replace(',','.').astype(float)

# %%
dya3m = "DY (3M) ACUMULADO"
dya6m = "DY (6M) ACUMULADO"
dya12m = "DY (12M) ACUMULADO"
dyano = "DY ANO"
vpreco = "Variação Preço".upper()
rperiodo = "Rentab. Período".upper()
raperiodo = "Rentab. Acumulada".upper()
dy3media = "DY (3M) Média".upper()
dy6media = "DY (6M) Média".upper()
dy12media = "DY (12M) Média".upper()
dypatrimonial = "DY Patrimonial".upper()
rpatac="Rentab. Patr. Acumulada".upper()
rper="RENTAB. PATR. PERÍODO".upper()
lqd = "LIQUIDEZ DIÁRIA (R$)"
#volt = "VOLATILIDADE"
#vf = "Vacância Física".upper()
#vfin = "Vacância Financeira".upper()

# %%
lista = [dya3m,
dya6m ,
dya12m,
dyano,
vpreco ,
rperiodo ,
raperiodo ,
dy3media ,
dy6media,
dy12media ,
dypatrimonial ,
rpatac,
rper]

# %%
for elemento in lista:
  print(elemento)
  FII_df[f"{elemento}"] = FII_df[f"{elemento}"].str.replace(',','.').astype(float)
# Out:
# DY (3M) ACUMULADO
# DY (6M) ACUMULADO
# DY (12M) ACUMULADO
# DY ANO
# VARIAÇÃO PREÇO
# RENTAB. PERÍODO
# RENTAB. ACUMULADA
# DY (3M) MÉDIA
# DY (6M) MÉDIA
# DY (12M) MÉDIA
# DY PATRIMONIAL
# RENTAB. PATR. ACUMULADA
# RENTAB. PATR. PERÍODO

# %%
np.max(FII_df[f'{dy}'])
# Out:
# 12.52

# %%
FII_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FUNDOS                   452 non-null    object
#  1   SETOR                    451 non-null    object
#  2   PREÇO ATUAL (R$)         416 non-null    float64
#  3   LIQUIDEZ DIÁRIA (R$)     408 non-null    float64
#  4   P/VP                     386 non-null    float64
#  5   ÚLTIMO DIVIDENDO         452 non-null    float64
#  6   DIVIDEND YIELD           417 non-null    float64
#  7   DY (3M) ACUMULADO        417 non-null    float64
#  8   DY (6M) ACUMULADO        417 non-null    float64
#  9   DY (12M) ACUMULADO       417 non-null    float64
#  10  DY (3M) MÉDIA            417 non-null    float64
#  11  DY (6M) MÉDIA            417 non-null    float64
#  12  DY (12M) MÉDIA           417 non-null    float64
#  13  DY ANO                   416 non-null    float64
#  14  VARIAÇÃO PREÇO           417 non-null    float64
#  15  RENTAB. PERÍODO          417 non-null    float64
#  16  RENTAB. ACUMULADA        313 non-null    float64
#  17  PATRIMÔNIO LÍQUIDO       415 non-null    float64
#  18  VPA                      296 non-null    float64
#  19  P/VPA                    288 non-null    float64
#  20  DY PATRIMONIAL           298 non-null    float64
#  21  VARIAÇÃO PATRIMONIAL     298 non-null    object
#  22  RENTAB. PATR. PERÍODO    298 non-null    float64
#  23  RENTAB. PATR. ACUMULADA  298 non-null    float64
#  24  QUANT. ATIVOS            452 non-null    int64
#  25  VOLATILIDADE             403 non-null    float64
#  26  NUM. COTISTAS            452 non-null    object
#  27  TAX. GESTÃO              0 non-null      float64
#  28  TAX. PERFORMANCE         0 non-null      float64
#  29  TAX. ADMINISTRAÇÃO       0 non-null      float64
# dtypes: float64(25), int64(1), object(4)
# memory usage: 106.1+ KB

# %%
 # Contagem de valores NaN de cada variável
# De forma particular, cada analista escolherá se aquela quantidade de NaNs serão ignorados ou não

FII_df.isna().sum()/len(FII_df)*100
# Out:
# FUNDOS                       0.000000
# SETOR                        0.221239
# PREÇO ATUAL (R$)             7.964602
# LIQUIDEZ DIÁRIA (R$)         9.734513
# P/VP                        14.601770
# ÚLTIMO DIVIDENDO             0.000000
# DIVIDEND YIELD               7.743363
# DY (3M) ACUMULADO            7.743363
# DY (6M) ACUMULADO            7.743363
# DY (12M) ACUMULADO           7.743363
# DY (3M) MÉDIA                7.743363
# DY (6M) MÉDIA                7.743363
# DY (12M) MÉDIA               7.743363
# DY ANO                       7.964602
# VARIAÇÃO PREÇO               7.743363
# RENTAB. PERÍODO              7.743363
# RENTAB. ACUMULADA           30.752212
# PATRIMÔNIO LÍQUIDO           8.185841
# VPA                         34.513274
# P/VPA                       36.283186
# DY PATRIMONIAL              34.070796
# VARIAÇÃO PATRIMONIAL        34.070796
# RENTAB. PATR. PERÍODO       34.070796
# RENTAB. PATR. ACUMULADA     34.070796
# QUANT. ATIVOS                0.000000
# VOLATILIDADE                10.840708
# NUM. COTISTAS                0.000000
# TAX. GESTÃO                100.000000
# TAX. PERFORMANCE           100.000000
# TAX. ADMINISTRAÇÃO         100.000000
# dtype: float64

# %%
#FII_df.dropna(subset = ['Preço Atual (R$)'.upper(), 'Dividend Yield'.upper(), 'Setor'.upper()], inplace = True)
FII_df.dropna(subset = [ 'DY (12M) acumulado'.upper(),'DY (12M) média'.upper(), 'P/VP'.upper(),'VOLATILIDADE'.upper()], inplace = True)
FII_df.shape
# Out:
# (347, 30)

# %%
FII_df
# Out:
#      FUNDOS                     SETOR  PREÇO ATUAL (R$)  LIQUIDEZ DIÁRIA (R$)  \
# 0    AAZQ11                INDEFINIDO              9.06             800151.05
# 1    ABCP11                 SHOPPINGS             76.68              64689.36
# 2    AFHI11                    PAPÉIS             98.30            1500508.45
# 4    AIEC11        LAJES CORPORATIVAS             52.23             480959.68
# 5    AJFI11                 SHOPPINGS              9.74             800840.36
# ..      ...                       ...               ...                   ...
# 445  XPPR11        LAJES CORPORATIVAS             22.30             484840.45
# 446  XPSF11           FUNDO DE FUNDOS              8.33             525668.86
# 448  YUFI11  FUNDO DE DESENVOLVIMENTO            105.00               5044.33
# 450  ZAVI11                INDEFINIDO            129.09             682267.50
# 451  ZIFI11  FUNDO DE DESENVOLVIMENTO            849.99               4362.87
#
#      P/VP  ÚLTIMO DIVIDENDO  DIVIDEND YIELD  DY (3M) ACUMULADO  \
# 0    0.94              0.12            1.31               3.90
# 1    0.76              0.50            0.64               2.34
# 2    1.02              0.95            0.97               2.93
# 4    0.62              0.71            1.35               3.07
# 5    0.78              0.08            0.81               1.64
# ..    ...               ...             ...                ...
# 445  0.34              0.07            0.31               0.93
# 446  0.96              0.08            0.89               2.66
# 448  1.03              0.39            0.00               0.00
# 450  0.97              1.34            1.01               3.01
# 451  0.71              3.31            0.00               0.00
#
#      DY (6M) ACUMULADO  DY (12M) ACUMULADO  ...  DY PATRIMONIAL  \
# 0                 7.85               15.52  ...            1.25
# 1                 5.00                9.44  ...            0.81
# 2                 6.09               12.79  ...            0.98
# 4                 8.11               15.03  ...            0.20
# 5                 1.64                1.64  ...             NaN
# ..                 ...                 ...  ...             ...
# 445               2.43                5.08  ...            0.11
# 446               5.45               11.20  ...            0.87
# 448               0.00                1.09  ...             NaN
# 450               5.85               11.22  ...             NaN
# 451               0.00                0.00  ...             NaN
#
#      VARIAÇÃO PATRIMONIAL  RENTAB. PATR. PERÍODO  RENTAB. PATR. ACUMULADA  \
# 0                   0,00                    0.00                     0.00
# 1                  10,34                   11.23                    19.14
# 2                   1,71                    2.71                     9.15
# 4                 -10,18                  -10.00                    -8.96
# 5                     NaN                    NaN                      NaN
# ..                    ...                    ...                      ...
# 445               -11,91                  -11.82                   -15.15
# 446                 3,71                    4.61                   -89.06
# 448                   NaN                    NaN                      NaN
# 450                   NaN                    NaN                      NaN
# 451                   NaN                    NaN                      NaN
#
#      QUANT. ATIVOS  VOLATILIDADE  NUM. COTISTAS  TAX. GESTÃO  \
# 0                0         13.22         27.598          NaN
# 1                1         15.42         16.988          NaN
# 2                0          8.10         31.221          NaN
# 4                4         16.84              1          NaN
# 5                0         15.02         11.173          NaN
# ..             ...           ...            ...          ...
# 445              3         27.67         54.104          NaN
# 446              0         12.99         64.992          NaN
# 448             28        268.47             62          NaN
# 450             10         22.86          5.692          NaN
# 451              0         74.32             73          NaN
#
#      TAX. PERFORMANCE  TAX. ADMINISTRAÇÃO
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 4                 NaN                 NaN
# 5                 NaN                 NaN
# ..                ...                 ...
# 445               NaN                 NaN
# 446               NaN                 NaN
# 448               NaN                 NaN
# 450               NaN                 NaN
# 451               NaN                 NaN
#
# [347 rows x 30 columns]

# %%
df = FII_df[FII_df['LIQUIDEZ DIÁRIA (R$)'.upper()] > 100000] #50 mil

# %%
df = df[df['PATRIMÔNIO LÍQUIDO'.upper()] > 10000000] # 20 milhoes

# %% [markdown]
# Lista de FIAGROs

# %%
# Lista de FIAGROs
fiagro = ['FZDB',"FZDA",'AAZQ','BBGO','AMAZ','CPTR','DCRA','EGAF','AGRX','RZAG','JGPX','FGAA','GCRA','GRWA','HGAG','IDGO','IAAG','RURA','USDA','KNCA','KOPA','LSAG','NCRA','NEXG','OIAG','PLCA','RZEO','IAGR','CRAA','SNAG','VGIA','VCRA','XPCA']
for i in range(0,len(fiagro)):
  fiagro[i] = fiagro[i] + "11"

# %%
df
# Out:
#      FUNDOS                             SETOR  PREÇO ATUAL (R$)  \
# 0    AAZQ11                        INDEFINIDO              9.06
# 2    AFHI11                            PAPÉIS             98.30
# 4    AIEC11                LAJES CORPORATIVAS             52.23
# 5    AJFI11                         SHOPPINGS              9.74
# 7    ALZM11                   FUNDO DE FUNDOS              8.47
# ..      ...                               ...               ...
# 443  XPLG11  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS            109.05
# 444  XPML11                         SHOPPINGS            116.85
# 445  XPPR11                LAJES CORPORATIVAS             22.30
# 446  XPSF11                   FUNDO DE FUNDOS              8.33
# 450  ZAVI11                        INDEFINIDO            129.09
#
#      LIQUIDEZ DIÁRIA (R$)  P/VP  ÚLTIMO DIVIDENDO  DIVIDEND YIELD  \
# 0               800151.05  0.94              0.12            1.31
# 2              1500508.45  1.02              0.95            0.97
# 4               480959.68  0.62              0.71            1.35
# 5               800840.36  0.78              0.08            0.81
# 7               186783.77  1.00              0.09            0.98
# ..                    ...   ...               ...             ...
# 443            5371325.14  0.98              0.78            0.71
# 444           11898597.55  1.05              0.90            0.76
# 445             484840.45  0.34              0.07            0.31
# 446             525668.86  0.96              0.08            0.89
# 450             682267.50  0.97              1.34            1.01
#
#      DY (3M) ACUMULADO  DY (6M) ACUMULADO  DY (12M) ACUMULADO  ...  \
# 0                 3.90               7.85               15.52  ...
# 2                 2.93               6.09               12.79  ...
# 4                 3.07               8.11               15.03  ...
# 5                 1.64               1.64                1.64  ...
# 7                 3.23               6.17               11.55  ...
# ..                 ...                ...                 ...  ...
# 443               2.12               4.29                8.49  ...
# 444               2.31               4.62                9.31  ...
# 445               0.93               2.43                5.08  ...
# 446               2.66               5.45               11.20  ...
# 450               3.01               5.85               11.22  ...
#
#      DY PATRIMONIAL  VARIAÇÃO PATRIMONIAL  RENTAB. PATR. PERÍODO  \
# 0              1.25                 0,00                    0.00
# 2              0.98                 1,71                    2.71
# 4              0.20               -10,18                  -10.00
# 5               NaN                   NaN                    NaN
# 7              1.06               -90,83                  -90.73
# ..              ...                   ...                    ...
# 443            0.70                -1,83                   -1.14
# 444            0.81                10,14                   11.04
# 445            0.11               -11,91                  -11.82
# 446            0.87                 3,71                    4.61
# 450             NaN                   NaN                    NaN
#
#      RENTAB. PATR. ACUMULADA  QUANT. ATIVOS  VOLATILIDADE  NUM. COTISTAS  \
# 0                       0.00              0         13.22         27.598
# 2                       9.15              0          8.10         31.221
# 4                      -8.96              4         16.84              1
# 5                        NaN              0         15.02         11.173
# 7                     -90.34              0         17.22          9.254
# ..                       ...            ...           ...            ...
# 443                    10.36             20         10.84        338.621
# 444                    18.99             14         11.74        437.270
# 445                   -15.15              3         27.67         54.104
# 446                   -89.06              0         12.99         64.992
# 450                      NaN             10         22.86          5.692
#
#      TAX. GESTÃO  TAX. PERFORMANCE  TAX. ADMINISTRAÇÃO
# 0            NaN               NaN                 NaN
# 2            NaN               NaN                 NaN
# 4            NaN               NaN                 NaN
# 5            NaN               NaN                 NaN
# 7            NaN               NaN                 NaN
# ..           ...               ...                 ...
# 443          NaN               NaN                 NaN
# 444          NaN               NaN                 NaN
# 445          NaN               NaN                 NaN
# 446          NaN               NaN                 NaN
# 450          NaN               NaN                 NaN
#
# [218 rows x 30 columns]

# %%
#df = df[df['P/VPA'].astype(float) < 1]
df = df[df['P/VP'].astype(float) <= 10]

# %%
for i in range(0,len(fiagro)):
  df.loc[df['FUNDOS'] == f'{fiagro[i]}', 'SETOR'] = 'FIAGRO'

# %%
df
# Out:
#      FUNDOS                             SETOR  PREÇO ATUAL (R$)  \
# 0    AAZQ11                            FIAGRO              9.06
# 2    AFHI11                            PAPÉIS             98.30
# 4    AIEC11                LAJES CORPORATIVAS             52.23
# 5    AJFI11                         SHOPPINGS              9.74
# 7    ALZM11                   FUNDO DE FUNDOS              8.47
# ..      ...                               ...               ...
# 443  XPLG11  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS            109.05
# 444  XPML11                         SHOPPINGS            116.85
# 445  XPPR11                LAJES CORPORATIVAS             22.30
# 446  XPSF11                   FUNDO DE FUNDOS              8.33
# 450  ZAVI11                        INDEFINIDO            129.09
#
#      LIQUIDEZ DIÁRIA (R$)  P/VP  ÚLTIMO DIVIDENDO  DIVIDEND YIELD  \
# 0               800151.05  0.94              0.12            1.31
# 2              1500508.45  1.02              0.95            0.97
# 4               480959.68  0.62              0.71            1.35
# 5               800840.36  0.78              0.08            0.81
# 7               186783.77  1.00              0.09            0.98
# ..                    ...   ...               ...             ...
# 443            5371325.14  0.98              0.78            0.71
# 444           11898597.55  1.05              0.90            0.76
# 445             484840.45  0.34              0.07            0.31
# 446             525668.86  0.96              0.08            0.89
# 450             682267.50  0.97              1.34            1.01
#
#      DY (3M) ACUMULADO  DY (6M) ACUMULADO  DY (12M) ACUMULADO  ...  \
# 0                 3.90               7.85               15.52  ...
# 2                 2.93               6.09               12.79  ...
# 4                 3.07               8.11               15.03  ...
# 5                 1.64               1.64                1.64  ...
# 7                 3.23               6.17               11.55  ...
# ..                 ...                ...                 ...  ...
# 443               2.12               4.29                8.49  ...
# 444               2.31               4.62                9.31  ...
# 445               0.93               2.43                5.08  ...
# 446               2.66               5.45               11.20  ...
# 450               3.01               5.85               11.22  ...
#
#      DY PATRIMONIAL  VARIAÇÃO PATRIMONIAL  RENTAB. PATR. PERÍODO  \
# 0              1.25                 0,00                    0.00
# 2              0.98                 1,71                    2.71
# 4              0.20               -10,18                  -10.00
# 5               NaN                   NaN                    NaN
# 7              1.06               -90,83                  -90.73
# ..              ...                   ...                    ...
# 443            0.70                -1,83                   -1.14
# 444            0.81                10,14                   11.04
# 445            0.11               -11,91                  -11.82
# 446            0.87                 3,71                    4.61
# 450             NaN                   NaN                    NaN
#
#      RENTAB. PATR. ACUMULADA  QUANT. ATIVOS  VOLATILIDADE  NUM. COTISTAS  \
# 0                       0.00              0         13.22         27.598
# 2                       9.15              0          8.10         31.221
# 4                      -8.96              4         16.84              1
# 5                        NaN              0         15.02         11.173
# 7                     -90.34              0         17.22          9.254
# ..                       ...            ...           ...            ...
# 443                    10.36             20         10.84        338.621
# 444                    18.99             14         11.74        437.270
# 445                   -15.15              3         27.67         54.104
# 446                   -89.06              0         12.99         64.992
# 450                      NaN             10         22.86          5.692
#
#      TAX. GESTÃO  TAX. PERFORMANCE  TAX. ADMINISTRAÇÃO
# 0            NaN               NaN                 NaN
# 2            NaN               NaN                 NaN
# 4            NaN               NaN                 NaN
# 5            NaN               NaN                 NaN
# 7            NaN               NaN                 NaN
# ..           ...               ...                 ...
# 443          NaN               NaN                 NaN
# 444          NaN               NaN                 NaN
# 445          NaN               NaN                 NaN
# 446          NaN               NaN                 NaN
# 450          NaN               NaN                 NaN
#
# [218 rows x 30 columns]

# %%
#df=df.dropna(subset = ['P/VPA'])
df=df.dropna(subset = ['P/VP'])

# %%
len(df.index)
linhas_div = len(df[ df['DY (12M) Acumulado'.upper()] > 0 ].index)
print(linhas_div)
# Out:
# 211

# %%
df = df[df['P/VP'] > 0.1]

# %%
df
# Out:
#      FUNDOS                             SETOR  PREÇO ATUAL (R$)  \
# 0    AAZQ11                            FIAGRO              9.06
# 2    AFHI11                            PAPÉIS             98.30
# 4    AIEC11                LAJES CORPORATIVAS             52.23
# 5    AJFI11                         SHOPPINGS              9.74
# 7    ALZM11                   FUNDO DE FUNDOS              8.47
# ..      ...                               ...               ...
# 443  XPLG11  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS            109.05
# 444  XPML11                         SHOPPINGS            116.85
# 445  XPPR11                LAJES CORPORATIVAS             22.30
# 446  XPSF11                   FUNDO DE FUNDOS              8.33
# 450  ZAVI11                        INDEFINIDO            129.09
#
#      LIQUIDEZ DIÁRIA (R$)  P/VP  ÚLTIMO DIVIDENDO  DIVIDEND YIELD  \
# 0               800151.05  0.94              0.12            1.31
# 2              1500508.45  1.02              0.95            0.97
# 4               480959.68  0.62              0.71            1.35
# 5               800840.36  0.78              0.08            0.81
# 7               186783.77  1.00              0.09            0.98
# ..                    ...   ...               ...             ...
# 443            5371325.14  0.98              0.78            0.71
# 444           11898597.55  1.05              0.90            0.76
# 445             484840.45  0.34              0.07            0.31
# 446             525668.86  0.96              0.08            0.89
# 450             682267.50  0.97              1.34            1.01
#
#      DY (3M) ACUMULADO  DY (6M) ACUMULADO  DY (12M) ACUMULADO  ...  \
# 0                 3.90               7.85               15.52  ...
# 2                 2.93               6.09               12.79  ...
# 4                 3.07               8.11               15.03  ...
# 5                 1.64               1.64                1.64  ...
# 7                 3.23               6.17               11.55  ...
# ..                 ...                ...                 ...  ...
# 443               2.12               4.29                8.49  ...
# 444               2.31               4.62                9.31  ...
# 445               0.93               2.43                5.08  ...
# 446               2.66               5.45               11.20  ...
# 450               3.01               5.85               11.22  ...
#
#      DY PATRIMONIAL  VARIAÇÃO PATRIMONIAL  RENTAB. PATR. PERÍODO  \
# 0              1.25                 0,00                    0.00
# 2              0.98                 1,71                    2.71
# 4              0.20               -10,18                  -10.00
# 5               NaN                   NaN                    NaN
# 7              1.06               -90,83                  -90.73
# ..              ...                   ...                    ...
# 443            0.70                -1,83                   -1.14
# 444            0.81                10,14                   11.04
# 445            0.11               -11,91                  -11.82
# 446            0.87                 3,71                    4.61
# 450             NaN                   NaN                    NaN
#
#      RENTAB. PATR. ACUMULADA  QUANT. ATIVOS  VOLATILIDADE  NUM. COTISTAS  \
# 0                       0.00              0         13.22         27.598
# 2                       9.15              0          8.10         31.221
# 4                      -8.96              4         16.84              1
# 5                        NaN              0         15.02         11.173
# 7                     -90.34              0         17.22          9.254
# ..                       ...            ...           ...            ...
# 443                    10.36             20         10.84        338.621
# 444                    18.99             14         11.74        437.270
# 445                   -15.15              3         27.67         54.104
# 446                   -89.06              0         12.99         64.992
# 450                      NaN             10         22.86          5.692
#
#      TAX. GESTÃO  TAX. PERFORMANCE  TAX. ADMINISTRAÇÃO
# 0            NaN               NaN                 NaN
# 2            NaN               NaN                 NaN
# 4            NaN               NaN                 NaN
# 5            NaN               NaN                 NaN
# 7            NaN               NaN                 NaN
# ..           ...               ...                 ...
# 443          NaN               NaN                 NaN
# 444          NaN               NaN                 NaN
# 445          NaN               NaN                 NaN
# 446          NaN               NaN                 NaN
# 450          NaN               NaN                 NaN
#
# [216 rows x 30 columns]

# %% [markdown]
# Lista de FIAGROs

# %%
fiagro = ['FZDB',"FZDA",'AAZQ','BBGO','AMAZ','CPTR','DCRA','EGAF','AGRX','RZAG','JGPX','FGAA','GCRA','GRWA','HGAG','IDGO','IAAG','RURA','USDA','KNCA','KOPA','LSAG','NCRA','NEXG','OIAG','PLCA','RZEO','IAGR','CRAA','SNAG','VGIA','VCRA','XPCA']
for i in range(0,len(fiagro)):
  fiagro[i] = fiagro[i] + "11"

# %%
ranking = pd.DataFrame()
linhas = len(df.index)
linhas_div = len(df[ df['DY (12M) Acumulado'.upper()] > 0 ].index)
ranking['pos'] = range(1,linhas_div+1)
ranking['Div. Yied. (12M) Acumulado'] = df[ df['DY (12M) Acumulado'.upper()] > 0 ].sort_values(by=['DY (12M) Acumulado'.upper()], ascending=False)['FUNDOS'][:linhas_div].values
ranking['D.Y.'] = df[ df['DY (12M) Acumulado'.upper()] > 0 ].sort_values(by=['DY (12M) Acumulado'.upper()], ascending=False)['DY (12M) Acumulado'.upper()][:linhas_div].values
#ranking['D.Y.'] = ranking['D.Y.'].map(lambda n: '{:.2%}'.format(n/100))
ranking['p/vpa'] = df[ df['DY (12M) Acumulado'.upper()] > 0 ].sort_values(by=['DY (12M) Acumulado'.upper()], ascending=False)['P/VP'][:linhas_div].values
#ranking['p/vpa'] = ranking['p/vpa'].map(lambda n: '{:.2}'.format(n/100))
ranking['Setor'] = df[ df['DY (12M) Acumulado'.upper()] > 0 ].sort_values(by=['DY (12M) Acumulado'.upper()], ascending=False)['Setor'.upper()][:linhas_div].values
#ranking['Setor P/VPA'] = df[ df['P/VPA'] > 0 ].sort_values(by=['DY (12M)Acumulado'], ascending=False)['Setor'][:linhas_div].values

ranking[' <> '] = " _|_ "
ranking['P/VPA'] = df.sort_values(by=['P/VP'], ascending=True)['FUNDOS'][:linhas_div].values
ranking['Valor P/VPA'] = df.sort_values(by=['P/VP'], ascending=True)['P/VP'][:linhas_div].values
#ranking['Valor P/VPA'] = ranking['Valor P/VPA'].map(lambda n: '{:.2}'.format(n/100))
ranking['Setor P/VPA'] = df[ df['P/VP'] > 0 ].sort_values(by=['P/VP'], ascending=True)['Setor'.upper()][:linhas_div].values
ranking['d.y.'] = df.sort_values(by=['P/VP'], ascending=True)['DY (12M) Acumulado'.upper()][:linhas_div].values
ranking['d.y.'] = ranking['d.y.'].map(lambda n: '{:.2%}'.format(n/100))
#ranking['P/L'] = df[ df['P/L'] > 0 ].sort_values(by=['P/L'])['Papel'][:150].values

ranking[' {} '] = " _|_ "
ranking['Volatilidade'] = df.sort_values(by=['VOLATILIDADE'], ascending=True)['FUNDOS'][:linhas_div].values
ranking['Vol'] = df.sort_values(by=['VOLATILIDADE'], ascending=True)['VOLATILIDADE'][:linhas_div].values
ranking['Setor vol'] = df[ df['VOLATILIDADE'] > 0 ].sort_values(by=['VOLATILIDADE'], ascending=True)['Setor'.upper()][:linhas_div].values
ranking['d.y.'] = df.sort_values(by=['VOLATILIDADE'], ascending=True)['DY (12M) Acumulado'.upper()][:linhas_div].values
ranking['P. L.'] = df.sort_values(by=['VOLATILIDADE'], ascending=True)['PATRIMÔNIO LÍQUIDO'.upper()][:linhas_div].values
ranking['P. L.'] = ranking['P. L.'].map(lambda n: '{:.3}B'.format(n/1000000000))

# %% [markdown]
# # **4. Filtrando os Fundos Imobiliários**

# %% [markdown]
# ---
# **Iniciando as análises de Fundos Imobiliários**
#
# ---

# %% [markdown]
# -- A tabela abaixo mostra primeiro selecionando os fundos com maiores dividend yield acumulado dos 12 últimos meses. A coluna <> é só para separar as tabelas. A tabela após <> é selecionado os fundos com os menores P/VPA

# %% [markdown]
# *P/VPA (Preço/Valor Patrimonial da Ação) é um indicador muito utilizado na análise fundamentalista. Ele relaciona o preço da ação ao valor patrimonial proporcional a ela. Indica quanto os acionistas topam pagar, no momento, pelo patrimônio líquido da companhia.
#
# *Dividend Yield, abreviadamente DY, é uma expressão inglesa que traduzida literalmente significa rendimento do dividendo. É um índice criado para medir a rentabilidade dos dividendos de uma empresa em relação ao preço de suas ações.

# %%
ranking.head(200)
# Out:
#      pos Div. Yied. (12M) Acumulado    D.Y.  p/vpa                     Setor  \
# 0      1                     XPHT11  115.46   0.71                    HOTÉIS
# 1      2                     PATC11   20.14   0.91  FUNDO DE DESENVOLVIMENTO
# 2      3                     HTMX11   18.80   1.19                    HOTÉIS
# 3      4                     KIVO11   16.55   0.99                    PAPÉIS
# 4      5                     CACR11   16.47   1.02                    PAPÉIS
# ..   ...                        ...     ...    ...                       ...
# 195  196                     NCHB11    3.57   0.94                    PAPÉIS
# 196  197                     KORE11    3.40   1.09        LAJES CORPORATIVAS
# 197  198                     SNME11    3.36   1.01                INDEFINIDO
# 198  199                     SEED11    3.27   1.07                INDEFINIDO
# 199  200                     CLIN11    3.16   0.97           FUNDO DE FUNDOS
#
#        <>    P/VPA  Valor P/VPA               Setor P/VPA   d.y.    {}   \
# 0     _|_   TORD11         0.15                     MISTO   0.00   _|_
# 1     _|_   HCTR11         0.32                    PAPÉIS   4.92   _|_
# 2     _|_   XPPR11         0.34        LAJES CORPORATIVAS   9.72   _|_
# 3     _|_   VSLH11         0.35                    PAPÉIS  13.20   _|_
# 4     _|_   HOFC11         0.42        LAJES CORPORATIVAS  15.75   _|_
# ..     ...     ...          ...                       ...    ...    ...
# 195   _|_   RBVA11         1.03                    VAREJO  11.52   _|_
# 196   _|_   VVPR11         1.04                     MISTO   9.71   _|_
# 197   _|_   TGAR11         1.04  FUNDO DE DESENVOLVIMENTO  11.46   _|_
# 198   _|_   HGCR11         1.04                    PAPÉIS  14.01   _|_
# 199   _|_   PNDL11         1.04  FUNDO DE DESENVOLVIMENTO   1.03   _|_
#
#     Volatilidade    Vol                         Setor vol    P. L.
# 0         SPMO11   0.42                        INDEFINIDO   0.263B
# 1         BLCP11   0.87  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS   0.257B
# 2         VVPR11   3.43                             MISTO   0.226B
# 3         SNAG11   5.23                            FIAGRO   0.504B
# 4         CRAA11   6.86                            FIAGRO  0.0505B
# ..           ...    ...                               ...      ...
# 195       SNLG11  34.14  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS  0.0655B
# 196       HOFC11  34.78                LAJES CORPORATIVAS   0.263B
# 197       TORD11  35.95                             MISTO   0.443B
# 198       DEVA11  37.63                            PAPÉIS    1.38B
# 199       JCCJ11  37.89                            PAPÉIS    0.31B
#
# [200 rows x 15 columns]

# %% [markdown]
# -- Selecionando agora os fundos com a maior média de dividend yield dos ultimos 12 meses

# %%
ranking = pd.DataFrame()
linhas = len(df.index)
classificacao_str = "DY (12M) Média".upper()
linhas_div = len(df[ df[f'{classificacao_str}'] > 0 ].index)
ranking['pos'] = range(1,linhas_div+1)
ranking['Div. Yied. (12M)Média'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['FUNDOS'][:linhas_div].values
ranking['D.Y.'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)[f'{classificacao_str}'][:linhas_div].values
ranking['D.Y.'] = ranking['D.Y.'].map(lambda n: '{:.2%}'.format(n/100))
ranking['p/vpa'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['P/VP'][:linhas_div].values
#ranking['p/vpa'] = ranking['p/vpa'].map(lambda n: '{:.2}'.format(n/100))
ranking['Setor'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['Setor'.upper()][:linhas_div].values
#ranking['Setor P/VPA'] = df[ df['P/VPA'] > 0 ].sort_values(by=['DY (12M)Acumulado'], ascending=False)['Setor'][:linhas_div].values

ranking[' <> '] = " _|_ "

# %% [markdown]
# ---
# **Análise de Fundos Imobiliários**: Abaixo está a lista dos fundos com as maiores médias do últimos 12 meses do dividend yield de cada fundo. Além disso, ao lado está o fator P/VPA (preço sobre Valor patrimonial)
#
# ---

# %%
ranking.head(200)
# Out:
#      pos Div. Yied. (12M)Média   D.Y.  p/vpa  \
# 0      1                XPHT11  9.62%   0.71
# 1      2                PATC11  1.68%   0.91
# 2      3                CLIN11  1.58%   0.97
# 3      4                HTMX11  1.57%   1.19
# 4      5                CRAA11  1.43%   1.03
# ..   ...                   ...    ...    ...
# 195  196                RBRP11  0.51%   0.75
# 196  197                HSRE11  0.43%   1.14
# 197  198                XPPR11  0.42%   0.34
# 198  199                BLCP11  0.41%   0.81
# 199  200                CPOF11  0.36%   0.92
#
#                                 Setor    <>
# 0                              HOTÉIS   _|_
# 1            FUNDO DE DESENVOLVIMENTO   _|_
# 2                     FUNDO DE FUNDOS   _|_
# 3                              HOTÉIS   _|_
# 4                              FIAGRO   _|_
# ..                                ...    ...
# 195                LAJES CORPORATIVAS   _|_
# 196                             MISTO   _|_
# 197                LAJES CORPORATIVAS   _|_
# 198  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS   _|_
# 199                             MISTO   _|_
#
# [200 rows x 6 columns]

# %% [markdown]
# -- Selecionando agora os fundos com a maior média do dividend yield dos ultimos 6 meses

# %%
ranking = pd.DataFrame()
linhas = len(df.index)
classificacao_str = "DY (6M) Média".upper()
linhas_div = len(df[ df[f'{classificacao_str}'] > 0 ].index)
ranking['pos'] = range(1,linhas_div+1)
ranking['Div. Yied. (6M)Média'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['FUNDOS'][:linhas_div].values
ranking['D.Y.'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)[f'{classificacao_str}'][:linhas_div].values
ranking['D.Y.'] = ranking['D.Y.'].map(lambda n: '{:.2%}'.format(n/100))
ranking['p/vpa'] = df[ df[f'{classificacao_str}'] > 0.1 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['P/VP'][:linhas_div].values
#ranking['p/vpa'] = ranking['p/vpa'].map(lambda n: '{:.2}'.format(n/100))
ranking['Setor'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['Setor'.upper()][:linhas_div].values
#ranking['Setor P/VPA'] = df[ df['P/VPA'] > 0 ].sort_values(by=['DY (12M)Acumulado'], ascending=False)['Setor'][:linhas_div].values

ranking[' <> '] = " _|_ "

# %% [markdown]
# ---
# **Análise de Fundos Imobiliários**: Abaixo está a lista das maiores médias do últimos 6 meses do dividendo yield de cada fundo. Além disso, ao lado está o fator P/VPA (preço sobre Valor patrimonial)
#
# ---

# %%
ranking.head(200)
# Out:
#      pos Div. Yied. (6M)Média   D.Y.  p/vpa                             Setor  \
# 0      1               BLCA11  2.56%   0.85                        INDEFINIDO
# 1      2               PATC11  2.34%   0.91          FUNDO DE DESENVOLVIMENTO
# 2      3               CLIN11  1.58%   0.97                   FUNDO DE FUNDOS
# 3      4               HTMX11  1.53%   1.19                            HOTÉIS
# 4      5              BBFI11B  1.52%   0.62                LAJES CORPORATIVAS
# ..   ...                  ...    ...    ...                               ...
# 195  196               FPAB11  0.52%   0.56                LAJES CORPORATIVAS
# 196  197               NCHB11  0.46%   0.94                            PAPÉIS
# 197  198               XPPR11  0.41%   0.34                LAJES CORPORATIVAS
# 198  199               BLCP11  0.40%   0.81  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 199  200               CPOF11  0.36%   0.92                             MISTO
#
#        <>
# 0     _|_
# 1     _|_
# 2     _|_
# 3     _|_
# 4     _|_
# ..     ...
# 195   _|_
# 196   _|_
# 197   _|_
# 198   _|_
# 199   _|_
#
# [200 rows x 6 columns]

# %% [markdown]
# -- Selecionando agora os fundos com a maior média do dividend yield dos ultimos 3 meses

# %%
ranking = pd.DataFrame()
linhas = len(df.index)
classificacao_str = "DY (3M) Média".upper()
linhas_div = len(df[ df[f'{classificacao_str}'] > 0 ].index)
ranking['pos'] = range(1,linhas_div+1)
ranking['Div. Yied. (3M) Média'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['FUNDOS'][:linhas_div].values
ranking['D.Y.'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)[f'{classificacao_str}'][:linhas_div].values
ranking['D.Y.'] = ranking['D.Y.'].map(lambda n: '{:.2%}'.format(n/100))
ranking['p/vpa'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['P/VP'][:linhas_div].values
#ranking['p/vpa'] = ranking['p/vpa'].map(lambda n: '{:.2}'.format(n/100))
ranking['Setor'] = df[ df[f'{classificacao_str}'] > 0 ].sort_values(by=[f'{classificacao_str}'], ascending=False)['Setor'.upper()][:linhas_div].values
#ranking['Setor P/VPA'] = df[ df['P/VPA'] > 0 ].sort_values(by=['DY (12M)Acumulado'], ascending=False)['Setor'][:linhas_div].values

ranking[' <> '] = " _|_ "

# %% [markdown]
# ---
# **Análise de Fundos Imobiliários**: Abaixo está a lista das maiores médias do últimos 3 meses do dividendo yield de cada fundo. Além disso, ao lado está o fator P/VPA (preço sobre Valor patrimonial)
#
# ---

# %%
ranking.head(200)
# Out:
#      pos Div. Yied. (3M) Média   D.Y.  p/vpa  \
# 0      1               BBFI11B  2.35%   0.62
# 1      2                PATC11  1.79%   0.91
# 2      3                BLCA11  1.61%   0.85
# 3      4                CLIN11  1.58%   0.97
# 4      5                VCRA11  1.36%   0.78
# ..   ...                   ...    ...    ...
# 195  196                ARCT11  0.43%   0.87
# 196  197                BLCP11  0.41%   0.81
# 197  198                MGCR11  0.39%   0.96
# 198  199                CPOF11  0.36%   0.92
# 199  200                HBCR11  0.31%   1.01
#
#                                 Setor    <>
# 0                  LAJES CORPORATIVAS   _|_
# 1            FUNDO DE DESENVOLVIMENTO   _|_
# 2                          INDEFINIDO   _|_
# 3                     FUNDO DE FUNDOS   _|_
# 4                              FIAGRO   _|_
# ..                                ...    ...
# 195  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS   _|_
# 196  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS   _|_
# 197                            PAPÉIS   _|_
# 198                             MISTO   _|_
# 199                        INDEFINIDO   _|_
#
# [200 rows x 6 columns]

# %% [markdown]
# ---
# # **Filtrando por Setores**
#
# ---

# %%
setores_str = ["Lajes Corporativas","Imóveis Industriais e Logísticos","Papéis","Fiagro","Indefinido","Misto","Fundo de Desenvolvimento","Fundo de Fundos","Shoppings","Agências de Bancos","Educacional","Hospitalar","Hotéis","Imóveis Comerciais - Outros","Imóveis Residenciais",
"Outros","Varejo"]
print(len(setores_str))
# Out:
# 17

# %% [markdown]
# ---
# **D.Y. 12 meses acumulado**:  Maiores dividend yield acumulado dos últimos 12 meses de cada fundo, separados por setor:
#
# ---

# %%
criterio_str = "DY (3M) Acumulado"

for i in range (0,len(setores_str)):
  ranking = df.loc[df['SETOR'] == f'{setores_str[i].upper()}']
  ranking2 = pd.DataFrame()
  linhas_div = len(ranking[ ranking[f'{criterio_str}'.upper()] > 0 ])
  print(f"SETOR: {setores_str[i].upper()}")
  ranking2['pos'] = range(1,linhas_div+1)
  ranking2['D. Y. (3M) Acum'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['FUNDOS'][:linhas_div].values
  ranking2['D.Y.'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)[f'{criterio_str}'.upper()][:linhas_div].values
  ranking2['p/vpa'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['P/VP'][:linhas_div].values
  ranking2['Setor'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['Setor'.upper()][:linhas_div].values
  display(ranking2.head(15))
  print("\n")
# Out:
# SETOR: LAJES CORPORATIVAS
#     pos D. Y. (3M) Acum  D.Y.  p/vpa               Setor
# 0     1         BBFI11B  7.06   0.62  LAJES CORPORATIVAS
# 1     2          KORE11  3.40   1.09  LAJES CORPORATIVAS
# 2     3          AIEC11  3.07   0.62  LAJES CORPORATIVAS
# 3     4          BROF11  2.84   0.55  LAJES CORPORATIVAS
# 4     5          GTWR11  2.76   0.83  LAJES CORPORATIVAS
# 5     6          FATN11  2.73   0.93  LAJES CORPORATIVAS
# 6     7          RECT11  2.68   0.46  LAJES CORPORATIVAS
# 7     8          CXCO11  2.68   0.81  LAJES CORPORATIVAS
# 8     9          HOFC11  2.41   0.42  LAJES CORPORATIVAS
# 9    10          TEPP11  2.40   0.97  LAJES CORPORATIVAS
# 10   11          VINO11  2.17   0.73  LAJES CORPORATIVAS
# 11   12          BRCR11  2.05   0.57  LAJES CORPORATIVAS
# 12   13          PVBI11  1.95   1.01  LAJES CORPORATIVAS
# 13   14          FLMA11  1.87   0.67  LAJES CORPORATIVAS
# 14   15          HGRE11  1.78   0.85  LAJES CORPORATIVAS
# SETOR: IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
#     pos D. Y. (3M) Acum  D.Y.  p/vpa                             Setor
# 0     1          RZAT11  3.39   1.00  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 1     2          BLMG11  3.28   0.49  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 2     3          OULG11  3.00   0.45  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 3     4          GARE11  2.80   0.98  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 4     5          SNLG11  2.68   0.87  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 5     6          BTAL11  2.64   0.66  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 6     7          PATL11  2.61   0.70  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 7     8          TRBL11  2.55   0.96  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 8     9          SDIL11  2.49   1.01  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 9    10          LVBI11  2.40   1.02  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 10   11          LGCP11  2.40   0.83  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 11   12          NEWL11  2.35   0.85  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 12   13          PQAG11  2.32   1.02  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 13   14          RBRL11  2.32   0.83  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 14   15          HSLG11  2.28   0.95  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# SETOR: PAPÉIS
#     pos D. Y. (3M) Acum  D.Y.  p/vpa   Setor
# 0     1          NAVT11  4.06   0.99  PAPÉIS
# 1     2          CACR11  3.92   1.02  PAPÉIS
# 2     3          DEVA11  3.84   0.47  PAPÉIS
# 3     4          RZAK11  3.84   0.98  PAPÉIS
# 4     5          URPR11  3.65   0.85  PAPÉIS
# 5     6          IBCR11  3.53   0.82  PAPÉIS
# 6     7          KIVO11  3.41   0.99  PAPÉIS
# 7     8          HABT11  3.41   0.94  PAPÉIS
# 8     9          KNHY11  3.38   1.04  PAPÉIS
# 9    10          VGIR11  3.36   1.02  PAPÉIS
# 10   11          RBHY11  3.26   0.96  PAPÉIS
# 11   12          ARRI11  3.26   1.03  PAPÉIS
# 12   13          JPPA11  3.24   0.91  PAPÉIS
# 13   14          GCRI11  3.24   0.89  PAPÉIS
# 14   15          SADI11  3.18   0.92  PAPÉIS
# SETOR: FIAGRO
#     pos D. Y. (3M) Acum  D.Y.  p/vpa   Setor
# 0     1          VCRA11  4.09   0.78  FIAGRO
# 1     2          GCRA11  4.01   0.70  FIAGRO
# 2     3          AAZQ11  3.90   0.94  FIAGRO
# 3     4          JGPX11  3.86   0.97  FIAGRO
# 4     5          VGIA11  3.70   0.86  FIAGRO
# 5     6          EGAF11  3.63   0.95  FIAGRO
# 6     7          CPTR11  3.62   0.91  FIAGRO
# 7     8          OIAG11  3.61   0.86  FIAGRO
# 8     9          RZAG11  3.61   0.90  FIAGRO
# 9    10          CRAA11  3.55   1.03  FIAGRO
# 10   11          FGAA11  3.46   0.95  FIAGRO
# 11   12          XPCA11  3.30   0.94  FIAGRO
# 12   13          KNCA11  3.20   0.99  FIAGRO
# 13   14          BBGO11  3.14   0.87  FIAGRO
# 14   15          SNAG11  3.12   1.00  FIAGRO
# SETOR: INDEFINIDO
#     pos D. Y. (3M) Acum  D.Y.  p/vpa       Setor
# 0     1          BLCA11  4.83   0.85  INDEFINIDO
# 1     2          BTRA11  3.77   0.52  INDEFINIDO
# 2     3          SNEL11  3.45   1.43  INDEFINIDO
# 3     4          SNME11  3.36   1.01  INDEFINIDO
# 4     5          MANA11  3.26   0.98  INDEFINIDO
# 5     6          KNUQ11  3.22   1.02  INDEFINIDO
# 6     7          BIME11  3.21   0.84  INDEFINIDO
# 7     8          RINV11  3.21   1.02  INDEFINIDO
# 8     9          CYCR11  3.19   0.98  INDEFINIDO
# 9    10          GAME11  3.03   0.94  INDEFINIDO
# 10   11          ZAVI11  3.01   0.97  INDEFINIDO
# 11   12          RBRX11  2.97   0.99  INDEFINIDO
# 12   13          SPXS11  2.94   0.98  INDEFINIDO
# 13   14          CPSH11  2.82   0.93  INDEFINIDO
# 14   15          KCRE11  2.82   0.97  INDEFINIDO
# SETOR: MISTO
#     pos D. Y. (3M) Acum  D.Y.  p/vpa  Setor
# 0     1          OURE11  3.45   0.80  MISTO
# 1     2          VGHF11  2.96   0.99  MISTO
# 2     3          VIUR11  2.66   0.84  MISTO
# 3     4          RZTR11  2.63   0.96  MISTO
# 4     5          TORD11  2.51   0.15  MISTO
# 5     6          VVPR11  2.47   1.04  MISTO
# 6     7          SARE11  2.43   0.51  MISTO
# 7     8          EVBI11  2.28   1.00  MISTO
# 8     9          ALZR11  2.02   1.11  MISTO
# 9    10          JSRE11  1.87   0.67  MISTO
# 10   11          HGRU11  1.85   1.08  MISTO
# 11   12          SAPI11  1.82   0.89  MISTO
# 12   13          KNRI11  1.81   1.02  MISTO
# 13   14          HSRE11  1.69   1.14  MISTO
# 14   15          CPOF11  0.71   0.92  MISTO
# SETOR: FUNDO DE DESENVOLVIMENTO
#    pos D. Y. (3M) Acum  D.Y.  p/vpa                     Setor
# 0    1          PATC11  5.38   0.91  FUNDO DE DESENVOLVIMENTO
# 1    2          MFII11  3.45   0.94  FUNDO DE DESENVOLVIMENTO
# 2    3          TGAR11  3.17   1.04  FUNDO DE DESENVOLVIMENTO
# 3    4          BRIP11  0.70   0.91  FUNDO DE DESENVOLVIMENTO
# SETOR: FUNDO DE FUNDOS
#     pos D. Y. (3M) Acum  D.Y.  p/vpa            Setor
# 0     1          ALZM11  3.23   1.00  FUNDO DE FUNDOS
# 1     2          CLIN11  3.16   0.97  FUNDO DE FUNDOS
# 2     3          JSAF11  2.91   1.01  FUNDO DE FUNDOS
# 3     4          OUFF11  2.80   0.89  FUNDO DE FUNDOS
# 4     5          TMPS11  2.77   0.94  FUNDO DE FUNDOS
# 5     6          VIFI11  2.69   0.89  FUNDO DE FUNDOS
# 6     7          RVBI11  2.66   0.92  FUNDO DE FUNDOS
# 7     8          KISU11  2.66   0.94  FUNDO DE FUNDOS
# 8     9          XPSF11  2.66   0.96  FUNDO DE FUNDOS
# 9    10          DVFF11  2.64   0.86  FUNDO DE FUNDOS
# 10   11          BBFO11  2.62   0.90  FUNDO DE FUNDOS
# 11   12          BPFF11  2.54   0.92  FUNDO DE FUNDOS
# 12   13          CPFF11  2.46   0.91  FUNDO DE FUNDOS
# 13   14          HFOF11  2.43   0.96  FUNDO DE FUNDOS
# 14   15          RBFF11  2.41   0.90  FUNDO DE FUNDOS
# SETOR: SHOPPINGS
#     pos D. Y. (3M) Acum  D.Y.  p/vpa      Setor
# 0     1          LASC11  4.04   0.84  SHOPPINGS
# 1     2          BPML11  2.99   0.72  SHOPPINGS
# 2     3          PQDP11  2.88   0.58  SHOPPINGS
# 3     4          FVPQ11  2.75   0.51  SHOPPINGS
# 4     5          VISC11  2.47   0.96  SHOPPINGS
# 5     6          HSML11  2.44   1.01  SHOPPINGS
# 6     7          MALL11  2.32   0.98  SHOPPINGS
# 7     8          XPML11  2.31   1.05  SHOPPINGS
# 8     9          HGBS11  2.29   0.99  SHOPPINGS
# 9    10          FIGS11  2.13   0.73  SHOPPINGS
# 10   11          AJFI11  1.64   0.78  SHOPPINGS
# 11   12          SHPH11  1.48   0.96  SHOPPINGS
# 12   13          GSFI11  0.03   0.54  SHOPPINGS
# SETOR: AGÊNCIAS DE BANCOS
#    pos D. Y. (3M) Acum  D.Y.  p/vpa               Setor
# 0    1          BBRC11  2.87   1.10  AGÊNCIAS DE BANCOS
# 1    2          BBPO11  2.78   1.03  AGÊNCIAS DE BANCOS
# 2    3          TVRI11  2.78   1.03  AGÊNCIAS DE BANCOS
# SETOR: EDUCACIONAL
#    pos D. Y. (3M) Acum  D.Y.  p/vpa        Setor
# 0    1          RBED11  2.69   0.97  EDUCACIONAL
# 1    2          FCFL11  2.10   1.00  EDUCACIONAL
# SETOR: HOSPITALAR
#    pos D. Y. (3M) Acum  D.Y.  p/vpa       Setor
# 0    1          NSLU11  2.44   0.93  HOSPITALAR
# 1    2          HUCG11  0.40   1.06  HOSPITALAR
# SETOR: HOTÉIS
#    pos D. Y. (3M) Acum  D.Y.  p/vpa   Setor
# 0    1          HTMX11  3.11   1.19  HOTÉIS
# 1    2          XPHT11  2.25   0.71  HOTÉIS
# SETOR: IMÓVEIS COMERCIAIS - OUTROS
#    pos D. Y. (3M) Acum  D.Y.  p/vpa                        Setor
# 0    1          LIFE11  3.58   0.98  IMÓVEIS COMERCIAIS - OUTROS
# 1    2          TRXF11  2.40   1.03  IMÓVEIS COMERCIAIS - OUTROS
# SETOR: IMÓVEIS RESIDENCIAIS
#    pos D. Y. (3M) Acum  D.Y.  p/vpa                 Setor
# 0    1          VCRR11  2.92   0.55  IMÓVEIS RESIDENCIAIS
# 1    2          JFLL11  2.44   0.73  IMÓVEIS RESIDENCIAIS
# SETOR: OUTROS
# Empty DataFrame
# Columns: [pos, D. Y. (3M) Acum, D.Y., p/vpa, Setor]
# Index: []
# SETOR: VAREJO
#    pos D. Y. (3M) Acum  D.Y.  p/vpa   Setor
# 0    1          MAXR11  2.90   0.65  VAREJO
# 1    2          RBVA11  2.65   1.03  VAREJO

# %% [markdown]
# ---

# %% [markdown]
# -----
#
# ---
# >

# %% [markdown]
# ---
# **Média D.Y. dos ultimos 12 meses**:  Abaixo está a lista das maiores médias dos últimos 12 meses do dividend yield de cada fundo, separadas por setor:
#
#
# ---

# %%
criterio_str = "DY (12M) Média"

for i in range (0,len(setores_str)):
  ranking = df.loc[df['SETOR'] == f'{setores_str[i].upper()}']
  ranking2 = pd.DataFrame()
  linhas_div = len(ranking[ ranking[f'{criterio_str}'.upper()] > 0 ])
  print(f"SETOR: {setores_str[i].upper()}")
  ranking2['pos'] = range(1,linhas_div+1)
  ranking2['D. Y. (12M) Media'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['FUNDOS'][:linhas_div].values
  ranking2['D.Y.'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)[f'{criterio_str}'.upper()][:linhas_div].values
  ranking2['p/vpa'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['P/VP'][:linhas_div].values
  ranking2['Setor'] = ranking[ ranking[f'{criterio_str}'.upper()] > 0 ].sort_values(by=[f'{criterio_str}'.upper()], ascending=False)['Setor'.upper()][:linhas_div].values
  display(ranking2.head(15))
  print("\n")
# Out:
# SETOR: LAJES CORPORATIVAS
#     pos D. Y. (12M) Media  D.Y.  p/vpa               Setor
# 0     1            AIEC11  1.25   0.62  LAJES CORPORATIVAS
# 1     2           BBFI11B  1.16   0.62  LAJES CORPORATIVAS
# 2     3            KORE11  1.13   1.09  LAJES CORPORATIVAS
# 3     4            BROF11  0.99   0.55  LAJES CORPORATIVAS
# 4     5            CXCO11  0.99   0.81  LAJES CORPORATIVAS
# 5     6            GTWR11  0.95   0.83  LAJES CORPORATIVAS
# 6     7            BREV11  0.90   0.89  LAJES CORPORATIVAS
# 7     8            FATN11  0.90   0.93  LAJES CORPORATIVAS
# 8     9            RECT11  0.89   0.46  LAJES CORPORATIVAS
# 9    10            HOFC11  0.81   0.42  LAJES CORPORATIVAS
# 10   11            FPAB11  0.81   0.56  LAJES CORPORATIVAS
# 11   12            TEPP11  0.75   0.97  LAJES CORPORATIVAS
# 12   13            VINO11  0.72   0.73  LAJES CORPORATIVAS
# 13   14            BRCR11  0.71   0.57  LAJES CORPORATIVAS
# 14   15            FLMA11  0.68   0.67  LAJES CORPORATIVAS
# SETOR: IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
#     pos D. Y. (12M) Media  D.Y.  p/vpa                             Setor
# 0     1            RZAT11  1.13   1.00  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 1     2            BLMG11  1.07   0.49  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 2     3            ARCT11  1.05   0.87  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 3     4            OULG11  1.03   0.45  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 4     5            SNLG11  0.96   0.87  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 5     6            GARE11  0.92   0.98  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 6     7            NEWL11  0.91   0.85  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 7     8            RELG11  0.89   0.43  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 8     9            SDIL11  0.86   1.01  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 9    10            PATL11  0.86   0.70  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 10   11            BTAL11  0.84   0.66  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 11   12            TRBL11  0.80   0.96  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 12   13            PQAG11  0.79   1.02  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 13   14            XPIN11  0.79   0.79  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# 14   15            HSLG11  0.79   0.95  IMÓVEIS INDUSTRIAIS E LOGÍSTICOS
# SETOR: PAPÉIS
#     pos D. Y. (12M) Media  D.Y.  p/vpa   Setor
# 0     1            KIVO11  1.38   0.99  PAPÉIS
# 1     2            CACR11  1.37   1.02  PAPÉIS
# 2     3            RZAK11  1.30   0.98  PAPÉIS
# 3     4            NAVT11  1.28   0.99  PAPÉIS
# 4     5            URPR11  1.27   0.85  PAPÉIS
# 5     6            VGIR11  1.22   1.02  PAPÉIS
# 6     7            IBCR11  1.20   0.82  PAPÉIS
# 7     8            RBHY11  1.19   0.96  PAPÉIS
# 8     9            JPPA11  1.19   0.91  PAPÉIS
# 9    10            HABT11  1.19   0.94  PAPÉIS
# 10   11            DEVA11  1.17   0.47  PAPÉIS
# 11   12            RBRY11  1.15   1.01  PAPÉIS
# 12   13            RBHG11  1.15   0.99  PAPÉIS
# 13   14            MCHY11  1.15   0.98  PAPÉIS
# 14   15            ARRI11  1.14   1.03  PAPÉIS
# SETOR: FIAGRO
#     pos D. Y. (12M) Media  D.Y.  p/vpa   Setor
# 0     1            CRAA11  1.43   1.03  FIAGRO
# 1     2            EGAF11  1.30   0.95  FIAGRO
# 2     3            AAZQ11  1.29   0.94  FIAGRO
# 3     4            GCRA11  1.29   0.70  FIAGRO
# 4     5            RZAG11  1.29   0.90  FIAGRO
# 5     6            VGIA11  1.29   0.86  FIAGRO
# 6     7            FGAA11  1.26   0.95  FIAGRO
# 7     8            VCRA11  1.26   0.78  FIAGRO
# 8     9            CPTR11  1.25   0.91  FIAGRO
# 9    10            OIAG11  1.24   0.86  FIAGRO
# 10   11            NCRA11  1.21   0.89  FIAGRO
# 11   12            XPCA11  1.20   0.94  FIAGRO
# 12   13            JGPX11  1.19   0.97  FIAGRO
# 13   14            BBGO11  1.13   0.87  FIAGRO
# 14   15            SNAG11  1.10   1.00  FIAGRO
# SETOR: INDEFINIDO
#     pos D. Y. (12M) Media  D.Y.  p/vpa       Setor
# 0     1            BLCA11  1.35   0.85  INDEFINIDO
# 1     2            RINV11  1.19   1.02  INDEFINIDO
# 2     3            SNEL11  1.18   1.43  INDEFINIDO
# 3     4            RBRX11  1.16   0.99  INDEFINIDO
# 4     5            SPXS11  1.14   0.98  INDEFINIDO
# 5     6            EQIR11  1.12   0.89  INDEFINIDO
# 6     7            SNME11  1.12   1.01  INDEFINIDO
# 7     8            BIME11  1.11   0.84  INDEFINIDO
# 8     9            CYCR11  1.11   0.98  INDEFINIDO
# 9    10            MANA11  1.10   0.98  INDEFINIDO
# 10   11            GAME11  1.09   0.94  INDEFINIDO
# 11   12            KNHF11  1.03   1.01  INDEFINIDO
# 12   13            CPSH11  1.02   0.93  INDEFINIDO
# 13   14            CXCI11  0.99   0.88  INDEFINIDO
# 14   15            KCRE11  0.96   0.97  INDEFINIDO
# SETOR: MISTO
#     pos D. Y. (12M) Media  D.Y.  p/vpa  Setor
# 0     1            OURE11  1.13   0.80  MISTO
# 1     2            VGHF11  1.13   0.99  MISTO
# 2     3            RZTR11  1.01   0.96  MISTO
# 3     4            TORD11  0.96   0.15  MISTO
# 4     5            SAPI11  0.91   0.89  MISTO
# 5     6            VIUR11  0.89   0.84  MISTO
# 6     7            SARE11  0.88   0.51  MISTO
# 7     8            VVPR11  0.81   1.04  MISTO
# 8     9            EVBI11  0.78   1.00  MISTO
# 9    10            HGRU11  0.76   1.08  MISTO
# 10   11            ALZR11  0.70   1.11  MISTO
# 11   12            KNRI11  0.64   1.02  MISTO
# 12   13            JSRE11  0.62   0.67  MISTO
# 13   14            HSRE11  0.43   1.14  MISTO
# 14   15            CPOF11  0.36   0.92  MISTO
# SETOR: FUNDO DE DESENVOLVIMENTO
#    pos D. Y. (12M) Media  D.Y.  p/vpa                     Setor
# 0    1            PATC11  1.68   0.91  FUNDO DE DESENVOLVIMENTO
# 1    2            BRIP11  1.29   0.91  FUNDO DE DESENVOLVIMENTO
# 2    3            MFII11  1.16   0.94  FUNDO DE DESENVOLVIMENTO
# 3    4            TGAR11  1.13   1.04  FUNDO DE DESENVOLVIMENTO
# SETOR: FUNDO DE FUNDOS
#     pos D. Y. (12M) Media  D.Y.  p/vpa            Setor
# 0     1            CLIN11  1.58   0.97  FUNDO DE FUNDOS
# 1     2            OUFF11  1.01   0.89  FUNDO DE FUNDOS
# 2     3            JSAF11  0.99   1.01  FUNDO DE FUNDOS
# 3     4            ALZM11  0.96   1.00  FUNDO DE FUNDOS
# 4     5            DVFF11  0.95   0.86  FUNDO DE FUNDOS
# 5     6            XPSF11  0.93   0.96  FUNDO DE FUNDOS
# 6     7            BBFO11  0.91   0.90  FUNDO DE FUNDOS
# 7     8            RVBI11  0.91   0.92  FUNDO DE FUNDOS
# 8     9            TMPS11  0.90   0.94  FUNDO DE FUNDOS
# 9    10            KISU11  0.88   0.94  FUNDO DE FUNDOS
# 10   11            BPFF11  0.88   0.92  FUNDO DE FUNDOS
# 11   12            VIFI11  0.87   0.89  FUNDO DE FUNDOS
# 12   13            KFOF11  0.87   1.02  FUNDO DE FUNDOS
# 13   14            RBFF11  0.85   0.90  FUNDO DE FUNDOS
# 14   15            CPFF11  0.84   0.91  FUNDO DE FUNDOS
# SETOR: SHOPPINGS
#     pos D. Y. (12M) Media  D.Y.  p/vpa      Setor
# 0     1            FVPQ11  0.91   0.51  SHOPPINGS
# 1     2            PQDP11  0.91   0.58  SHOPPINGS
# 2     3            AJFI11  0.82   0.78  SHOPPINGS
# 3     4            HSML11  0.81   1.01  SHOPPINGS
# 4     5            HGBS11  0.79   0.99  SHOPPINGS
# 5     6            VISC11  0.78   0.96  SHOPPINGS
# 6     7            XPML11  0.78   1.05  SHOPPINGS
# 7     8            FIGS11  0.77   0.73  SHOPPINGS
# 8     9            LASC11  0.72   0.84  SHOPPINGS
# 9    10            MALL11  0.72   0.98  SHOPPINGS
# 10   11            SHPH11  0.58   0.96  SHOPPINGS
# 11   12            BPML11  0.56   0.72  SHOPPINGS
# SETOR: AGÊNCIAS DE BANCOS
#    pos D. Y. (12M) Media  D.Y.  p/vpa               Setor
# 0    1            BBRC11  1.00   1.10  AGÊNCIAS DE BANCOS
# 1    2            BBPO11  0.94   1.03  AGÊNCIAS DE BANCOS
# 2    3            TVRI11  0.94   1.03  AGÊNCIAS DE BANCOS
# SETOR: EDUCACIONAL
#    pos D. Y. (12M) Media  D.Y.  p/vpa        Setor
# 0    1            RBED11  0.98   0.97  EDUCACIONAL
# 1    2            FCFL11  0.72   1.00  EDUCACIONAL
# SETOR: HOSPITALAR
#    pos D. Y. (12M) Media  D.Y.  p/vpa       Setor
# 0    1            NSLU11  0.83   0.93  HOSPITALAR
# 1    2            HUCG11  0.25   1.06  HOSPITALAR
# SETOR: HOTÉIS
#    pos D. Y. (12M) Media  D.Y.  p/vpa   Setor
# 0    1            XPHT11  9.62   0.71  HOTÉIS
# 1    2            HTMX11  1.57   1.19  HOTÉIS
# SETOR: IMÓVEIS COMERCIAIS - OUTROS
#    pos D. Y. (12M) Media  D.Y.  p/vpa                        Setor
# 0    1            LIFE11  1.27   0.98  IMÓVEIS COMERCIAIS - OUTROS
# 1    2            TRXF11  0.87   1.03  IMÓVEIS COMERCIAIS - OUTROS
# SETOR: IMÓVEIS RESIDENCIAIS
#    pos D. Y. (12M) Media  D.Y.  p/vpa                 Setor
# 0    1            VCRR11  0.95   0.55  IMÓVEIS RESIDENCIAIS
# 1    2            JFLL11  0.85   0.73  IMÓVEIS RESIDENCIAIS
# SETOR: OUTROS
# Empty DataFrame
# Columns: [pos, D. Y. (12M) Media, D.Y., p/vpa, Setor]
# Index: []
# SETOR: VAREJO
#    pos D. Y. (12M) Media  D.Y.  p/vpa   Setor
# 0    1            MAXR11  1.02   0.65  VAREJO
# 1    2            RBVA11  0.91   1.03  VAREJO

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# # Exportando para planilha "tabela_fii"

# %%
import datetime # para importar toda a biblioteca
# import datetime as dt # substituindo o nome datetime por dt dentro do código
# from datetime import date # quando se quer apenas 1 dos submódulos

# %%
data = datetime.date.today()


#print(data.ctime())

ano = data.year
mes = data.month
dia = data.day
#dia = dia -1
#hora = data.hora # erro!
#print(ano, mes, dia)
#data = data.replace(day=2)
#print(nova_data)
#print(data)
print(data)
print(f'{dia}/{mes}/{ano}')
# Out:
# 2024-04-05
# 5/4/2024

# %% [markdown]
# Código da planilha

# %%
wb=gc.open_by_key('1mWc_h8cubvNogLs9m50vrnSM66KFFuQ2a2gVeI6HLac')

# %% [markdown]
# ## Inserindo dado na aba "D.Y. Media"

# %% [markdown]
# Selecionando aba

# %%
ws=wb.worksheet('d.y. media')
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in refresh(self, request)
#     127         try:
# --> 128             self._retrieve_info(request)
#     129             self.token, self.expiry = _metadata.get_service_account_token(
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in _retrieve_info(self, request)
#     100         """
# --> 101         info = _metadata.get_service_account_info(
#     102             request, service_account=self._service_account_email
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py in get_service_account_info(request, service_account)
#     322     # for more on the use of 'recursive'.
# --> 323     return get(request, path, params={"recursive": "true"})
#     324
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/_metadata.py in get(request, path, root, params, recursive, retry_count, headers, return_none_for_not_found_error)
#     247
# --> 248     raise exceptions.TransportError(
#     249         "Failed to retrieve {} from the Google Compute Engine "
#
# TransportError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x7a6d4b18fe80>)
#
# The above exception was the direct cause of the following exception:
#
# RefreshError                              Traceback (most recent call last)
# <ipython-input-75-f8c0b5c281ce> in <cell line: 1>()
# ----> 1 ws=wb.worksheet('d.y. media')
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in worksheet(self, title)
#     312
#     313         """
# --> 314         sheet_data = self.fetch_sheet_metadata()
#     315         try:
#     316             item = finditem(
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in fetch_sheet_metadata(self, params)
#     261         url = SPREADSHEET_URL % self.id
#     262
# --> 263         r = self.client.request('get', url, params=params)
#     264
#     265         return r.json()
#
# /usr/local/lib/python3.10/dist-packages/gspread/client.py in request(self, method, endpoint, params, data, json, files, headers)
#      59             headers=None):
#      60
# ---> 61         response = getattr(self.session, method)(
#      62             endpoint,
#      63             json=json,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535
#     536         with TimeoutGuard(remaining_time) as guard:
# --> 537             self.credentials.before_request(auth_request, method, url, request_headers)
#     538         remaining_time = guard.remaining_timeout
#     539
#
# /usr/local/lib/python3.10/dist-packages/google/auth/credentials.py in before_request(self, request, method, url, headers)
#     226             self._non_blocking_refresh(request)
#     227         else:
# --> 228             self._blocking_refresh(request)
#     229
#     230         metrics.add_metric_header(headers, self._metric_header_for_usage())
#
# /usr/local/lib/python3.10/dist-packages/google/auth/credentials.py in _blocking_refresh(self, request)
#     189     def _blocking_refresh(self, request):
#     190         if not self.valid:
# --> 191             self.refresh(request)
#     192
#     193     def _non_blocking_refresh(self, request):
#
# /usr/local/lib/python3.10/dist-packages/google/auth/compute_engine/credentials.py in refresh(self, request)
#     132         except exceptions.TransportError as caught_exc:
#     133             new_exc = exceptions.RefreshError(caught_exc)
# --> 134             raise new_exc from caught_exc
#     135
#     136     @property
#
# RefreshError: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x7a6d4b18fe80>)

# %%
criterio_str = "DY (12M) Média"
tamanho_lista = 20 #quantidade de Fii selecionados por setor
elementos = ["Fundos",f'{criterio_str}','P/VP','PATRIMÔNIO LÍQUIDO','Volatilidade','Setor']
df_ordenado = df.sort_values(by=[f'{criterio_str}'.upper()], ascending=False)
ranking2 = pd.DataFrame()
for j in range(len(setores_str)):
  ranking = df_ordenado.loc[df['SETOR'] == f'{setores_str[j].upper()}']
  for i in range(len(elementos)):
    aux = pd.Series(ranking[f'{elementos[i]}'.upper()]).tolist()
    if i == 1:
      aux = [f'{numero}'.replace(".",",") + '%' for numero in aux]
    if i == 3:
      aux = [f'{round(numero/1000000000,2)}'.replace(".",",") + 'B' for numero in aux]
    if len(aux) > tamanho_lista:
      aux=list(islice(aux, tamanho_lista))
    while len(aux) < tamanho_lista:
      aux.append("-")

    ranking2[f"{elementos[i]}" + f"{j}"] = aux

# Ajustar o índice para iniciar em 1
ranking2.index = ranking2.index + 1
#ranking.reset_index(drop=True,inplace=True)

# %%
ranking2.tail(4)

# %%
cabecalho = ['Fundo','D.Y. media','P/VPA','Patri. Liq. ','Volatilidade','Setor']

i=0
while i < (len(setores_str)-1):
  for j in range(6):
    cabecalho.append(cabecalho[j])
  i += 1

print(cabecalho)

todos_registros = [cabecalho] + ranking2.to_numpy().tolist()
#todos_registros = [cabecalho]

ws.update(None, todos_registros )

# %%
todos_registros

# %%
ws.update('B23', f'{dia}/{mes}/{ano}' )

# %% [markdown]
# ---

# %% [markdown]
# ## Inserindo dados na aba "d.y. acumulado"

# %%
criterio_str = "DY (12M) Acumulado"

tamanho_lista = 20 #quantidade de Fii selecionados por setor
elementos = ["Fundos",f'{criterio_str}','P/VP','PATRIMÔNIO LÍQUIDO','Volatilidade','Setor']
df_ordenado = df.sort_values(by=[f'{criterio_str}'.upper()], ascending=False)
ranking2 = pd.DataFrame()
for j in range(len(setores_str)):
  ranking = df_ordenado.loc[df['SETOR'] == f'{setores_str[j].upper()}']
  for i in range(len(elementos)):
    aux = pd.Series(ranking[f'{elementos[i]}'.upper()]).tolist()
    if i == 1:
      aux = [f'{numero}'.replace(".",",") + '%' for numero in aux]
    if i == 3:
      aux = [f'{round(numero/1000000000,2)}'.replace(".",",") + 'B' for numero in aux]
    if len(aux) > tamanho_lista:
      aux=list(islice(aux, tamanho_lista))
    while len(aux) < tamanho_lista:
      aux.append("-")

    ranking2[f"{elementos[i]}" + f"{j}"] = aux

# Ajustar o índice para iniciar em 1
ranking2.index = ranking2.index + 1
#ranking.reset_index(drop=True,inplace=True)

# %% [markdown]
# Selecionando aba

# %%
ws=wb.worksheet('d.y. acumulado')

# %%
cabecalho = ['Fundo','D.Y. acum','P/VPA','Patri. Liq. ','Volatilidade','Setor']

i=0
while i < (len(setores_str)-1):
  for j in range(6):
    cabecalho.append(cabecalho[j])
  i += 1

print(cabecalho)

todos_registros = [cabecalho] + ranking2.to_numpy().tolist()

ws.update(None, todos_registros )

# %%
ws.update('B23', f'{dia}/{mes}/{ano}' )

# %% [markdown]
# ## Abaixo sao calculos aleatorios

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir variáveis
S0 = 100   # preço inicial da ação
mu = 0.05  # taxa de retorno esperada
sigma = 0.2  # desvio padrão do retorno

# Definir número de simulações e número de dias
n_simulacoes = 1000
n_dias = 252

# Gerar números aleatórios com base na distribuição normal
np.random.seed(123)
simulacoes_retorno = np.random.normal(loc=(mu/n_dias), scale=(sigma/np.sqrt(n_dias)), size=(n_dias, n_simulacoes))

# Calcular preços finais simulados
precos_finais = S0 * np.exp(np.cumsum(simulacoes_retorno, axis=0))

# Calcular média e desvio padrão dos preços finais simulados
media = np.mean(precos_finais[-1])
desvio_padrao = np.std(precos_finais[-1])

# Plotar histograma dos preços finais simulados
plt.hist(precos_finais[-1], bins=50, density=True, alpha=0.6, color='b')
plt.xlabel('Preço final')
plt.ylabel('Densidade')
plt.title('Simulação de Monte Carlo para precificação de ações')
plt.axvline(x=S0, linestyle='--', color='r', label='Preço inicial')
plt.axvline(x=media, linestyle='--', color='g', label='Preço médio final')
plt.legend()
plt.show()

# %%
C = 132
taxa = 1.121 # em %
i = taxa/100
n = 2*12-1 # tempo
M=0
for j in range(n+1):
  M += C*(1+i)**j
  #print(j+1)
print(f"M = $ {round(M,2)}")

# %%
print(4*12*3400)

# %%
print(54101*0.65/100)

# %% [markdown]
# $$ \frac{a}{2}$$

# %%
import numpy as np
from scipy.stats import norm

def black_scholes(call_put, S, K, T, r, sigma):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    if call_put == "call":
        option_price = S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    elif call_put == "put":
        option_price = K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    else:
        option_price = None

    return option_price

# Exemplo de uso
S = 67.57  # Preço atual da ação
K = 66.73  # Preço de exercício da opção
T = 12/252    # Tempo até a expiração (em anos)
r = 0.1275 # Taxa de juros livre de risco
sigma = 0.2757  # Volatilidade

call_price = black_scholes("call", S, K, T, r, sigma)
put_price = black_scholes("put", S, K, T, r, sigma)

print("Preço da opção de compra (Call Option):", call_price)
print("Preço da opção de venda (Put Option):", put_price)

# %%
import datetime # para importar toda a biblioteca
# import datetime as dt # substituindo o nome datetime por dt dentro do código
# from datetime import date # quando se quer apenas 1 dos submódulos

# %%
data = datetime.date(2021,9,25)
print(data)

print(data.ctime())

ano = data.year
mes = data.month
dia = data.day
#hora = data.hora # erro!
print(ano, mes, dia)

nova_data = data.replace(day=2)
print(nova_data)
print(data)

# %%
20
